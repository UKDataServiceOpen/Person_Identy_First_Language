# %% [markdown]
# # Import and get ready

# %%
# !pip install autocorrect          
from autocorrect import Speller   # things we need for spell checking
check = Speller(lang='en')

import csv                        # csv is for importing and working with csv files

import datetime
date = datetime.date.today()

import nltk                       # get nltk 
from nltk import word_tokenize    # and some of its key functions
from nltk import sent_tokenize    
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.corpus import wordnet                    # Finally, things we need for lemmatising!
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 
nltk.download('averaged_perceptron_tagger')        # Like a POS-tagger...
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('webtext')

import numpy as np
import os                         # os is a module for navigating your machine (e.g., file directories).
import pandas as pd
import statistics
import re                         # things we need for RegEx corrections

English_punctuation = "-!\"#$%&()'*+,./:;<=>?@[\]^_`{|}~''“”"      # Things for removing punctuation, stopwords and empty strings
table_punctuation = str.maketrans('','', English_punctuation)  

print("Succesfully imported necessary modules")    # The print statement is just a bit of encouragement!
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Requirement already satisfied: autocorrect in c:\python39\lib\site-packages (2.6.1)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mzyssjkc\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mzyssjkc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mzyssjkc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mzyssjkc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\mzyssjkc\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# Succesfully imported necessary modules

# %%
print(os.listdir("..\\for_analysis\\ESHG")) # This is how to see the contents of any folders shown in the last contents check
print(os.listdir("..\\counts\\ESHG")) # This is how to see the contents of any folders shown in the last contents check
# Out:
# ['2001abstractICHG.txt', '2002Abstracts.txt', '2003Abstracts.txt', '2004Abstracts.txt', '2005Abstracts.txt', '2006Abstracts.txt', '2007Abstracts.txt', '2008Abstracts.txt', '2009Abstracts.txt', '2010Abstracts.txt', '2011Abstracts.txt', '2012Abstracts.txt', '2013Abstracts.txt', '2014Abstracts.txt', '2015Abstracts.txt', '2016Abstracts.txt', '2017 electronic posters.txt', '2017 oral presentations.txt', '2017 posters.txt', '2018 electronic posters.txt', '2018 EMPAG.txt', '2018 oral presentation.txt', '2018 posters.txt', '2019 oral presentation.txt', '2019 posters.txt', '2019 posters2.txt', '2020 eposters.txt', '2020 interactive eposter.txt', '2020 oral presentation.txt', '2021 eposters.txt', '2021 oral presentations.txt']
# ['select.csv', 'totals.csv']

# %% [markdown]
# # Read in and check useful things

# %%
totals_df = pd.read_csv('..\\counts\\ESHG\\totals.csv', header=None)
totals_df.columns = ["filename", "abstracts"]
totals_df
# Out:
#                     filename  abstracts
# 0           2001abstractICHG       7805
# 1              2002Abstracts       5517
# 2              2003Abstracts       4539
# 3              2004Abstracts         13
# 4              2005Abstracts       7289
# 5              2006Abstracts       6026
# 6              2007Abstracts       7283
# 7              2008Abstracts       9794
# 8              2009Abstracts       7981
# 9              2010Abstracts       7795
# 10             2011Abstracts       9133
# 11             2012Abstracts       8777
# 12             2013Abstracts      10626
# 13             2014Abstracts       9041
# 14             2015Abstracts       7978
# 15             2016Abstracts      10734
# 16   2017 electronic posters       2409
# 17   2017 oral presentations        905
# 18              2017 posters       7091
# 19   2018 electronic posters       1959
# 20                2018 EMPAG        281
# 21    2018 oral presentation       1145
# 22              2018 posters       7044
# 23    2019 oral presentation       1075
# 24              2019 posters       6085
# 25             2019 posters2       1090
# 26             2020 eposters       2423
# 27  2020 interactive eposter       5996
# 28    2020 oral presentation       1171
# 29             2021 eposters       7247
# 30   2021 oral presentations       1097

# %%
raw_select_abstracts = []

with open('..\\counts\\ESHG\\select.csv', newline='', encoding = "ISO-8859-1") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        raw_select_abstracts.append(row)
        
select_abstracts = (list(filter(lambda x: x, raw_select_abstracts)))

# %%
select_df = pd.DataFrame.from_records(select_abstracts)
total_select = select_df.iloc[:,0].value_counts()

# %%
autism_count = select_df.iloc[:,0].value_counts().rename_axis('unique_values').to_frame('counts')

autism_count = autism_count.reset_index()
autism_count.columns = ['filename', 'autism_abstracts']

autism_count
# Out:
#                     filename  autism_abstracts
# 0              2013Abstracts               137
# 1              2016Abstracts               132
# 2              2015Abstracts               129
# 3              2014Abstracts               116
# 4              2012Abstracts               108
# 5              2011Abstracts               104
# 6               2018 posters                98
# 7               2019 posters                92
# 8   2020 interactive eposter                85
# 9              2010Abstracts                74
# 10             2008Abstracts                72
# 11              2017 posters                71
# 12             2021 eposters                68
# 13             2009Abstracts                42
# 14             2007Abstracts                41
# 15   2018 electronic posters                41
# 16   2017 electronic posters                36
# 17             2006Abstracts                35
# 18             2002Abstracts                33
# 19             2005Abstracts                32
# 20             2019 posters2                28
# 21          2001abstractICHG                21
# 22             2020 eposters                21
# 23             2003Abstracts                19
# 24    2020 oral presentation                19
# 25   2021 oral presentations                14
# 26    2019 oral presentation                12
# 27    2018 oral presentation                 8
# 28   2017 oral presentations                 5
# 29                2018 EMPAG                 1

# %%
merged_counts = pd.merge(totals_df, autism_count, on = 'filename')

# %%
merged_counts
# Out:
#                     filename  abstracts  autism_abstracts
# 0           2001abstractICHG       7805                21
# 1              2002Abstracts       5517                33
# 2              2003Abstracts       4539                19
# 3              2005Abstracts       7289                32
# 4              2006Abstracts       6026                35
# 5              2007Abstracts       7283                41
# 6              2008Abstracts       9794                72
# 7              2009Abstracts       7981                42
# 8              2010Abstracts       7795                74
# 9              2011Abstracts       9133               104
# 10             2012Abstracts       8777               108
# 11             2013Abstracts      10626               137
# 12             2014Abstracts       9041               116
# 13             2015Abstracts       7978               129
# 14             2016Abstracts      10734               132
# 15   2017 electronic posters       2409                36
# 16   2017 oral presentations        905                 5
# 17              2017 posters       7091                71
# 18   2018 electronic posters       1959                41
# 19                2018 EMPAG        281                 1
# 20    2018 oral presentation       1145                 8
# 21              2018 posters       7044                98
# 22    2019 oral presentation       1075                12
# 23              2019 posters       6085                92
# 24             2019 posters2       1090                28
# 25             2020 eposters       2423                21
# 26  2020 interactive eposter       5996                85
# 27    2020 oral presentation       1171                19
# 28             2021 eposters       7247                68
# 29   2021 oral presentations       1097                14

# %%
merged_counts['year'] = merged_counts['filename'].str.extract(r'(\d{4})')
merged_counts
# Out:
#                     filename  abstracts  autism_abstracts  year
# 0           2001abstractICHG       7805                21  2001
# 1              2002Abstracts       5517                33  2002
# 2              2003Abstracts       4539                19  2003
# 3              2005Abstracts       7289                32  2005
# 4              2006Abstracts       6026                35  2006
# 5              2007Abstracts       7283                41  2007
# 6              2008Abstracts       9794                72  2008
# 7              2009Abstracts       7981                42  2009
# 8              2010Abstracts       7795                74  2010
# 9              2011Abstracts       9133               104  2011
# 10             2012Abstracts       8777               108  2012
# 11             2013Abstracts      10626               137  2013
# 12             2014Abstracts       9041               116  2014
# 13             2015Abstracts       7978               129  2015
# 14             2016Abstracts      10734               132  2016
# 15   2017 electronic posters       2409                36  2017
# 16   2017 oral presentations        905                 5  2017
# 17              2017 posters       7091                71  2017
# 18   2018 electronic posters       1959                41  2018
# 19                2018 EMPAG        281                 1  2018
# 20    2018 oral presentation       1145                 8  2018
# 21              2018 posters       7044                98  2018
# 22    2019 oral presentation       1075                12  2019
# 23              2019 posters       6085                92  2019
# 24             2019 posters2       1090                28  2019
# 25             2020 eposters       2423                21  2020
# 26  2020 interactive eposter       5996                85  2020
# 27    2020 oral presentation       1171                19  2020
# 28             2021 eposters       7247                68  2021
# 29   2021 oral presentations       1097                14  2021

# %%
print(merged_counts['abstracts'].sum())
print(merged_counts['autism_abstracts'].sum())
# Out:
# 167336
# 1694

# %%
print(merged_counts[['year', 'abstracts']].groupby('year').sum('abstracts'))
#print(merged_counts['autism_abstracts'].sum())
# Out:
#       abstracts
# year
# 2001       7805
# 2002       5517
# 2003       4539
# 2005       7289
# 2006       6026
# 2007       7283
# 2008       9794
# 2009       7981
# 2010       7795
# 2011       9133
# 2012       8777
# 2013      10626
# 2014       9041
# 2015       7978
# 2016      10734
# 2017      10405
# 2018      10429
# 2019       8250
# 2020       9590
# 2021       8344

# %% [markdown]
# # Working with the contents of the selected abstracts

# %% [markdown]
# ##  Dump the content of the selected abtsracts into one big string

# %%
bag_of_abstracts = ""

for abstract in (select_abstracts):
    bag_of_abstracts += abstract[3]

# %% [markdown]
# ## tokenize that big string, and transform the tokens into lowercase

# %%
abstract_token_word = word_tokenize(bag_of_abstracts)
abstract_token_word_lower = [word.lower() for word in abstract_token_word]

print(abstract_token_word_lower[:10])
# Out:
# ['p08', '.10', 'rs4307059', 'and', 'rs4141463', 'study', 'in', 'an', 'italian', 'cohort']

# %% [markdown]
# ## Remove the punctuation from the lowercased tokens

# %%
abstract_t_w_l_np = [w.translate(table_punctuation) for w in abstract_token_word_lower]  
                                                               # Iterate over corpus_words, turning punctuation to nothing.
print(abstract_t_w_l_np[:10])
# Out:
# ['p08', '10', 'rs4307059', 'and', 'rs4141463', 'study', 'in', 'an', 'italian', 'cohort']

# %%
abstract_t_w_l_np = (list(filter(lambda x: x, abstract_t_w_l_np)))
print(abstract_t_w_l_np[:10])
# Out:
# ['p08', '10', 'rs4307059', 'and', 'rs4141463', 'study', 'in', 'an', 'italian', 'cohort']

# %% [markdown]
# ## Remove stopwords

# %%
print(sorted(stop_words))        # just an option to check what counts as a stopword if you want to see

# %%
abstract_t_w_l_np_nsw = []

for word in abstract_t_w_l_np:
    if word not in stop_words:
        abstract_t_w_l_np_nsw.append(word)
        
        
print(abstract_t_w_l_np_nsw[:10])
# Out:
# ['p08', '10', 'rs4307059', 'rs4141463', 'study', 'italian', 'cohort', 'neck', 'surgery', 'university']

# %% [markdown]
# ## Spell check the lowercased "real word" tokens

# %%
len(abstract_t_w_l_np_nsw)

# %%
# runs forever without finishing. Find alternative or skip it?

abstract_t_w_l_np_cs = []

for word in abstract_t_w_l_np_nsw:
    abstract_t_w_l_np_cs.append(check(word))    

print(abstract_t_w_l_np_cs[:10])

# %%
from nltk.stem.porter import PorterStemmer

porter = PorterStemmer()
abstract_t_w_l_np_nsw_stem = [porter.stem(word) for word in abstract_t_w_l_np_nsw]
print(abstract_t_w_l_np_nsw_stem[:10])
# Out:
# ['p08', '10', 'rs4307059', 'rs4141463', 'studi', 'italian', 'cohort', 'neck', 'surgeri', 'univers']

# %%
from collections import Counter
counts = Counter(abstract_t_w_l_np_nsw_stem)
print(type(counts))
# Out:
# <class 'collections.Counter'>

# %%
print(counts.most_common(100))
# Out:
# [('gene', 3535), ('none', 3535), ('patient', 3516), ('genet', 3106), ('de', 2423), ('univers', 2210), ('disord', 2201), ('autism', 2057), ('mutat', 1878), ('asd', 1736), ('clinic', 1705), ('studi', 1582), ('syndrom', 1560), ('delet', 1557), ('associ', 1535), ('variant', 1439), ('case', 1427), ('chromosom', 1398), ('hospit', 1252), ('use', 1240), ('medic', 1236), ('phenotyp', 1228), ('analysi', 1171), ('result', 1163), ('report', 1160), ('unit', 1126), ('c', 1115), ('famili', 1099), ('j', 1091), ('e', 1033), ('genom', 1025), ('two', 983), ('franc', 978), ('spectrum', 973), ('p', 958), ('includ', 958), ('region', 953), ('present', 947), ('sequenc', 934), ('diseas', 929), ('featur', 921), ('cnv', 906), ('identifi', 881), ('caus', 872), ('sever', 854), ('show', 804), ('delay', 794), ('disabl', 784), ('human', 770), ('itali', 762), ('institut', 756), ('one', 752), ('l', 731), ('medicin', 725), ('2', 720), ('intellectu', 713), ('r', 712), ('molecular', 707), ('duplic', 694), ('cell', 687), ('b', 683), ('detect', 667), ('affect', 664), ('g', 660), ('individu', 658), ('development', 647), ('involv', 646), ('develop', 636), ('rare', 633), ('1', 618), ('found', 608), ('research', 597), ('mental', 593), ('perform', 588), ('state', 582), ('also', 581), ('center', 581), ('abnorm', 576), ('n', 573), ('function', 570), ('k', 569), ('express', 568), ('differ', 562), ('f', 561), ('children', 561), ('method', 557), ('normal', 549), ('reveal', 539), ('autist', 538), ('year', 537), ('control', 536), ('test', 535), ('retard', 534), ('id', 528), ('brain', 524), ('novo', 518), ('number', 504), ('suggest', 499), ('character', 496), ('parent', 493)]

# %% [markdown]
# ## Person-first and identity first

# %%
# !pip install spacy
import re 
import string 
import nltk 
import spacy 
import pandas as pd 
import numpy as np 
import math 
from tqdm import tqdm 

from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy 

pd.set_option('display.max_colwidth', 200)
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\python39\\Scripts\\spacy.exe' -> 'c:\\python39\\Scripts\\spacy.exe.deleteme'
#
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# Collecting spacy
#   Using cached spacy-3.4.1-cp39-cp39-win_amd64.whl (11.8 MB)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\python39\lib\site-packages (from spacy) (8.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\python39\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python39\lib\site-packages (from spacy) (4.61.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python39\lib\site-packages (from spacy) (1.0.8)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from spacy) (56.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from spacy) (20.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python39\lib\site-packages (from spacy) (3.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python39\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\python39\lib\site-packages (from spacy) (0.6.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python39\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\python39\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\python39\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python39\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\python39\lib\site-packages (from spacy) (0.4.2)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python39\lib\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\python39\lib\site-packages (from spacy) (1.9.2)
# Requirement already satisfied: jinja2 in c:\python39\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python39\lib\site-packages (from spacy) (1.0.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python39\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\python39\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python39\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\python39\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.1)
# Requirement already satisfied: colorama in c:\python39\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\python39\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: langcodes, spacy

# %%
# !pip install spacy -q
import spacy
# !python -m spacy download en_core_web_lg -q
from nltk.corpus import webtext

nlp = spacy.load('en_core_web_lg')
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
person_identity = nltk.sent_tokenize(bag_of_abstracts)

# %%
type(person_identity)
# Out:
# list

# %%
person =""

for sentence in person_identity:
    if any(s in sentence for s in ['autisic', 'Autisic', 'autism', 'Autism']):
        person += sentence

# %%
len(person)
# Out:
# 631947

# %%
for tok in person_doc: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)
# Out:
# Patients --> nsubj --> NOUN
# 4 --> nummod --> NUM
# and --> cc --> CCONJ
# 5 --> conj --> NUM
# presented --> ROOT --> VERB
# with --> prep --> ADP
# autistic --> amod --> ADJ
# features --> pobj --> NOUN
# . --> punct --> PUNCT
# Primary --> amod --> ADJ
# microcephalies --> ROOT --> NOUN
# ( --> punct --> PUNCT
# MicroCephaly --> compound --> PROPN
# Primary --> compound --> PROPN
# Hereditary --> appos --> PROPN
# , --> punct --> PUNCT
# MCPH --> appos --> PROPN
# ) --> punct --> PUNCT
# We --> nsubj --> PRON
# report --> ROOT --> VERB
# two --> nummod --> NUM
# children --> dobj --> NOUN
# with --> prep --> ADP
# autistic --> amod --> ADJ
# behavior --> pobj --> NOUN
# , --> punct --> PUNCT
# mental --> amod --> ADJ
# retardation --> conj --> NOUN
# and --> cc --> CCONJ
# have --> aux --> AUX
# often --> advmod --> ADV
# been --> auxpass --> AUX
# presented --> conj --> VERB
# as --> prep --> ADP
# a --> det --> DET
# developmental --> amod --> ADJ
# disorders --> pobj --> NOUN
# resulting --> acl --> VERB
# in --> prep --> ADP
# dysmorphic --> amod --> ADJ
# features --> pobj --> NOUN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# present --> ROOT --> VERB
# a --> det --> DET
# 4 --> nummod --> NUM
# year --> npadvmod --> NOUN
# old --> amod --> ADJ
# girl --> nsubj --> NOUN
# with --> prep --> ADP
# mo- --> pobj --> NOUN
# showed --> ccomp --> VERB
# a --> det --> DET
# mutation --> compound --> NOUN
# spectrum --> dobj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# gene --> pobj --> NOUN
# in --> prep --> ADP
# Brazilian --> amod --> ADJ
# patients --> pobj --> NOUN
# with --> prep --> ADP
# tor --> nmod --> PROPN
# and --> cc --> CCONJ
# speech --> compound --> NOUN
# delay --> pobj --> NOUN
# , --> punct --> PUNCT
# mild --> amod --> ADJ
# ataxia --> conj --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# behavioral --> amod --> ADJ
# problems --> conj --> NOUN
# including --> prep --> VERB
# im- --> amod --> ADJ
# nonsyndromic --> amod --> ADJ
# sensorineural --> amod --> ADJ
# hearing --> compound --> NOUN
# loss --> pobj --> NOUN
# and --> cc --> CCONJ
# demonstrate --> conj --> VERB
# the --> det --> DET
# high --> amod --> ADJ
# genetic --> amod --> ADJ
# pulsivity --> dobj --> NOUN
# , --> punct --> PUNCT
# aggression --> conj --> NOUN
# and --> cc --> CCONJ
# mild --> amod --> ADJ
# autistic --> amod --> ADJ
# features.feeding --> conj --> NOUN
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# global --> amod --> ADJ
# DD --> conj --> PROPN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# , --> punct --> PUNCT
# central --> amod --> ADJ
# hypotonia --> conj --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# dystonia --> conj --> NOUN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# describe --> ROOT --> VERB
# a --> det --> DET
# male --> amod --> ADJ
# infant --> dobj --> NOUN
# with --> prep --> ADP
# taracts --> pobj --> NOUN
# , --> punct --> PUNCT
# global --> amod --> ADJ
# DD --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# . --> punct --> PUNCT
# AL --> compound --> PROPN
# RlaPr5g --> nsubjpass --> PROPN
# , --> punct --> PUNCT
# e --> amod --> NOUN
# ~200 --> compound --> NOUN
# - --> punct --> PUNCT
# kb --> compound --> NOUN
# deletion --> nsubjpass --> NOUN
# was --> auxpass --> AUX
# detected --> ROOT --> VERB
# in --> prep --> ADP
# chromosome --> nmod --> NOUN
# 22 --> nummod --> NUM
# encompas- --> amod --> ADJ
# seizures --> pobj --> NOUN
# and --> cc --> CCONJ
# obvious --> amod --> ADJ
# autistic --> amod --> ADJ
# behavior --> conj --> NOUN
# .She --> nsubj --> NOUN
# had --> conj --> VERB
# dysmorphic --> amod --> ADJ
# facies --> dobj --> NOUN
# and --> cc --> CCONJ
# large --> nsubj --> ADJ
# sing --> conj --> VERB
# the --> det --> DET
# gene --> dobj --> NOUN
# . --> punct --> PUNCT
# Using --> advcl --> VERB
# a --> det --> DET
# combination --> dobj --> NOUN
# of --> prep --> ADP
# bioinformatics --> compound --> NOUN
# tools --> pobj --> NOUN
# ( --> punct --> PUNCT
# MirWalk --> nmod --> PROPN
# , --> punct --> PUNCT
# lopmental --> amod --> PROPN
# diseases --> appos --> NOUN
# , --> punct --> PUNCT
# Williams --> compound --> PROPN
# Beuren --> compound --> PROPN
# Syndrome --> appos --> PROPN
# ( --> punct --> PUNCT
# WBS --> appos --> PROPN
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# the --> det --> DET
# 7q11.23 --> nummod --> PROPN
# CO --> compound --> PROPN
# - --> punct --> PUNCT
# ME --> compound --> PROPN
# - --> punct --> PUNCT
# TA --> nmod --> PROPN
# , --> punct --> PUNCT
# DAVID --> conj --> PROPN
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# have --> aux --> AUX
# identified --> ROOT --> VERB
# 4 --> nummod --> NUM
# candidate --> compound --> NOUN
# miRNAs --> dobj --> NOUN
# whose --> nsubj --> DET
# predicted --> relcl --> VERB
# microduplication --> dobj --> NOUN
# associated --> acl --> VERB
# to --> prep --> ADP
# autistic --> amod --> ADJ
# spectrum --> compound --> NOUN
# disorder --> pobj --> NOUN
# ( --> punct --> PUNCT
# 7dup --> appos --> PROPN
# - --> punct --> SYM
# ASD).We --> appos --> NOUN
# and --> cc --> CCONJ
# When --> advmod --> SCONJ
# stratifying --> conj --> VERB
# the --> det --> DET
# ND --> compound --> PROPN
# cohort --> dobj --> NOUN
# for --> prep --> ADP
# patients --> pobj --> NOUN
# with --> prep --> ADP
# epilepsy --> pobj --> NOUN
# , --> punct --> PUNCT
# othersrecentlyidentiï¬edtheupregulationofmiR-146aasa --> conj --> VERB
# we --> dative --> PRON
# identiï¬ed --> det --> DET
# signiï¬cant --> amod --> NOUN
# enrichment --> dobj --> NOUN
# of --> prep --> ADP
# DNV --> pobj --> PROPN
# in --> prep --> ADP
# 33 --> nummod --> NUM
# genes --> pobj --> NOUN
# , --> punct --> PUNCT
# common --> amod --> ADJ
# event --> appos --> NOUN
# in --> prep --> ADP
# various --> amod --> ADJ
# cell --> compound --> NOUN
# types --> pobj --> NOUN
# from --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# : --> punct --> PUNCT
# sevenofwhichwithpreviouslylimitedevidencefordisease --> amod --> PROPN
# olfactory --> compound --> PROPN
# mucosa --> compound --> PROPN
# stem --> compound --> NOUN
# cells --> appos --> NOUN
# , --> punct --> PUNCT
# skin --> compound --> NOUN
# ï¬broblast --> conj --> ADJ
# and --> cc --> CCONJ
# lympho- --> compound --> NOUN
# association --> conj --> PROPN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# lobe --> appos --> NOUN
# of --> prep --> ADP
# autistic --> amod --> ADJ
# children --> pobj --> NOUN
# ( --> punct --> PUNCT
# age --> appos --> NOUN
# 4â10 --> nummod --> NUM
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# not --> neg --> PART
# in --> prep --> ADP
# adolescents --> pobj --> NOUN
# found --> ROOT --> VERB
# that --> mark --> SCONJ
# genes --> nsubj --> NOUN
# involved --> acl --> VERB
# in --> prep --> ADP
# synaptic --> amod --> ADJ
# transmission --> pobj --> NOUN
# were --> ccomp --> AUX
# andadults --> attr --> NOUN
# . --> punct --> PUNCT
# Tounderstanditsrolesinearlydevelopment --> npadvmod --> PROPN
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# more --> advmod --> ADV
# frequently --> advmod --> ADV
# mutated --> ccomp --> VERB
# in --> prep --> ADP
# individuals --> pobj --> NOUN
# with --> prep --> ADP
# epilepsy --> pobj --> NOUN
# while --> mark --> SCONJ
# generated --> advcl --> VERB
# human --> amod --> ADJ
# H9 --> compound --> PROPN
# neural --> amod --> ADJ
# progenitor --> compound --> NOUN
# stem --> compound --> NOUN
# cells --> nsubj --> NOUN
# stably --> advmod --> ADV
# chromatin --> compound --> VERB
# modiï¬cation --> nsubjpass --> NOUN
# was --> auxpass --> AUX
# more --> advmod --> ADV
# frequently --> advmod --> ADV
# altered --> ccomp --> VERB
# in --> prep --> ADP
# over --> prep --> ADP
# expressing --> pcomp --> VERB
# miR-146a.cortical --> compound --> PRON
# samples --> dobj --> NOUN
# from --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# and --> cc --> CCONJ
# give --> conj --> VERB
# important --> amod --> ADJ
#   --> dep --> SPACE
# P09.061.A --> nmod --> SYM
# Comprehensive --> amod --> ADJ
# genetic --> amod --> ADJ
# analysis --> dobj --> NOUN
# of --> prep --> ADP
# intellectual --> amod --> ADJ
# disability --> pobj --> NOUN
# When --> advmod --> SCONJ
# a --> det --> DET
# seemingly --> advmod --> ADV
# heterozygous --> amod --> ADJ
# CNV --> nsubj --> PROPN
# turns --> advcl --> VERB
# out --> prt --> ADP
# to --> aux --> PART
# be --> xcomp --> AUX
# patients --> attr --> NOUN
# from --> prep --> ADP
# the --> det --> DET
# Kashubian --> amod --> ADJ
# population --> pobj --> NOUN
# using --> acl --> VERB
# homo- --> dobj --> NOUN
# compound --> dobj --> NOUN
# - --> punct --> PUNCT
# heterozygous --> acomp --> ADJ
# - --> punct --> PUNCT
# from --> prep --> ADP
# NRXN1 --> npadvmod --> PROPN
# - --> punct --> PUNCT
# associated --> amod --> VERB
# neu- --> compound --> PROPN
# zygosity --> compound --> PROPN
# mapping --> pobj --> NOUN
# and --> cc --> CCONJ
# exome --> npadvmod --> NOUN
# sequencing --> nmod --> VERB
# rodevelopmental --> amod --> ADJ
# disorder --> nsubj --> NOUN
# to --> prep --> ADP
# Pitt --> compound --> PROPN
# - --> punct --> PUNCT
# Hopkins --> npadvmod --> PROPN
# - --> punct --> PUNCT
# like --> pobj --> ADJ
# syn- --> compound --> PROPN
# drome --> nmod --> PROPN
# 2 --> nummod --> NUM
# A. --> compound --> NOUN
# Charzewska1 --> pobj --> NOUN
# , --> punct --> PUNCT
# T. --> compound --> PROPN
# Gambin1 --> appos --> PROPN
# , --> punct --> PUNCT
# J. --> compound --> PROPN
# Wierzba2 --> appos --> PROPN
# , --> punct --> PUNCT
# E. --> compound --> PROPN
# Kaczorowska2 --> conj --> PROPN
# , --> punct --> PUNCT
# E. --> compound --> PROPN
# Obersztyn1 --> conj --> PROPN
# , --> punct --> PUNCT
# B. --> compound --> PROPN
# WojtaÅ3 --> conj --> PROPN
# , --> punct --> PUNCT
# B. --> compound --> PROPN
# Gielniewski3 --> appos --> PROPN
# , --> punct --> PUNCT
# A. --> compound --> PROPN
# C. --> compound --> PROPN
# Teichmann1 --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Stiller1 --> conj --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# Schubert1 --> appos --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# Redler2 --> appos --> PROPN
# , --> punct --> PUNCT
# R. --> compound --> PROPN
# R. --> nmod --> PROPN
# Szlendak1,P.Chromo- --> conj --> PROPN
# autistic --> amod --> ADJ
# child --> appos --> NOUN
# with --> prep --> ADP
# intellectual --> amod --> ADJ
# disability --> pobj --> NOUN
# and --> cc --> CCONJ
# EEG --> conj --> PROPN
# anomalies --> conj --> VERB
# some --> det --> DET
# arrangement --> nsubj --> NOUN
# in --> prep --> ADP
# interphase --> compound --> NOUN
# nuclei --> pobj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# schizophrenia --> compound --> NOUN
# brain --> pobj --> NOUN
# was --> ccomp --> AUX
# com- --> nummod --> NOUN
# V. --> compound --> PROPN
# Seidel1 --> attr --> PROPN
# , --> punct --> PUNCT
# P. --> compound --> PROPN
# de --> nmod --> ADP
# Castro2 --> appos --> PROPN
# ; --> punct --> PUNCT
# pletely --> advmod --> ADV
# different --> advcl --> ADJ
# from --> prep --> ADP
# the --> det --> DET
# unaffected --> amod --> ADJ
# brain.before --> nmod --> NUM
# age --> pobj --> NOUN
# twelve --> nummod --> NUM
# months --> pobj --> NOUN
# , --> punct --> PUNCT
# her --> poss --> PRON
# language --> compound --> NOUN
# development --> nsubj --> NOUN
# stopped --> conj --> VERB
# and --> cc --> CCONJ
# autistic --> compound --> ADJ
# Supported --> conj --> VERB
# by --> agent --> ADP
# Russian --> compound --> PROPN
# Scientific --> compound --> PROPN
# Fund --> pobj --> PROPN
# ( --> punct --> PUNCT
# Grant --> nmod --> PROPN
# # --> nmod --> SYM
# 14 --> npadvmod --> NUM
# - --> punct --> SYM
# 35 --> nummod --> NUM
# - --> punct --> PUNCT
# 00060).In --> prep --> NUM
# conclusion --> dobj --> NOUN
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# provided --> ROOT --> VERB
# that --> mark --> SCONJ
# characterized --> csubj --> VERB
# by --> agent --> ADP
# several --> amod --> ADJ
# clinical --> amod --> ADJ
# abnormalities --> pobj --> NOUN
# , --> punct --> PUNCT
# such --> amod --> ADJ
# as --> prep --> ADP
# progressive --> amod --> ADJ
# DHPLC --> compound --> PROPN
# analysis --> pobj --> NOUN
# is --> ccomp --> AUX
# a --> det --> DET
# sensitive --> amod --> ADJ
# and --> cc --> CCONJ
# specific --> conj --> ADJ
# method --> attr --> NOUN
# to --> aux --> PART
# detect --> relcl --> VERB
# mutations --> dobj --> NOUN
# in --> prep --> ADP
# encephalopathy --> pobj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# behavior --> conj --> NOUN
# and --> cc --> CCONJ
# stereotyped --> amod --> ADJ
# hand --> compound --> NOUN
# movements --> conj --> NOUN
# . --> punct --> PUNCT
# T. --> compound --> PROPN
# Bautista --> compound --> PROPN
# - --> punct --> PUNCT
# Tirado --> dep --> PROPN
# : --> punct --> PUNCT
# None --> ROOT --> NOUN
# . --> punct --> PUNCT
# These --> det --> DET
# results --> nsubj --> NOUN
# confirm --> ROOT --> VERB
# the --> det --> DET
# heterogenei- --> compound --> PROPN
# ty --> dobj --> PROPN
# of --> prep --> ADP
# behavioral --> amod --> ADJ
# profile --> pobj --> NOUN
# in --> prep --> ADP
# FXS --> pobj --> PROPN
# and --> cc --> CCONJ
# the --> det --> DET
# common --> amod --> ADJ
# association --> conj --> NOUN
# between --> prep --> ADP
# FXS --> pobj --> PROPN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# disorders --> conj --> NOUN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# and --> cc --> CCONJ
# When --> advmod --> SCONJ
# stratifying --> conj --> VERB
# the --> det --> DET
# ND --> compound --> PROPN
# cohort --> dobj --> NOUN
# for --> prep --> ADP
# patients --> pobj --> NOUN
# with --> prep --> ADP
# epilepsy --> pobj --> NOUN
# , --> punct --> PUNCT
# othersrecentlyidentiï¬edtheupregulationofmiR-146aasa --> ROOT --> VERB
# we --> dative --> PRON
# identiï¬ed --> det --> DET
# signiï¬cant --> amod --> NOUN
# enrichment --> dobj --> NOUN
# of --> prep --> ADP
# DNV --> pobj --> PROPN
# in --> prep --> ADP
# 33 --> nummod --> NUM
# genes --> pobj --> NOUN
# , --> punct --> PUNCT
# common --> amod --> ADJ
# event --> appos --> NOUN
# in --> prep --> ADP
# various --> amod --> ADJ
# cell --> compound --> NOUN
# types --> pobj --> NOUN
# from --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# : --> punct --> PUNCT
# sevenofwhichwithpreviouslylimitedevidencefordisease --> amod --> PROPN
# olfactory --> compound --> PROPN
# mucosa --> compound --> PROPN
# stem --> compound --> NOUN
# cells --> appos --> NOUN
# , --> punct --> PUNCT
# skin --> compound --> NOUN
# ï¬broblast --> conj --> ADJ
# and --> cc --> CCONJ
# lympho- --> compound --> NOUN
# association --> conj --> PROPN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# lobe --> appos --> NOUN
# of --> prep --> ADP
# autistic --> amod --> ADJ
# children --> pobj --> NOUN
# ( --> punct --> PUNCT
# age --> appos --> NOUN
# 4â10 --> nummod --> NUM
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# not --> neg --> PART
# in --> prep --> ADP
# adolescents --> pobj --> NOUN
# found --> ROOT --> VERB
# that --> mark --> SCONJ
# genes --> nsubj --> NOUN
# involved --> acl --> VERB
# in --> prep --> ADP
# synaptic --> amod --> ADJ
# transmission --> pobj --> NOUN
# were --> ccomp --> AUX
# andadults --> attr --> NOUN
# . --> punct --> PUNCT
# Tounderstanditsrolesinearlydevelopment --> npadvmod --> PROPN
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# more --> advmod --> ADV
# frequently --> advmod --> ADV
# mutated --> ROOT --> VERB
# in --> prep --> ADP
# individuals --> pobj --> NOUN
# with --> prep --> ADP
# epilepsy --> pobj --> NOUN
# while --> mark --> SCONJ
# generated --> advcl --> VERB
# human --> amod --> ADJ
# H9 --> compound --> PROPN
# neural --> amod --> ADJ
# progenitor --> compound --> NOUN
# stem --> compound --> NOUN
# cells --> nsubj --> NOUN
# stably --> advmod --> ADV
# chromatin --> compound --> VERB
# modiï¬cation --> nsubjpass --> NOUN
# was --> auxpass --> AUX
# more --> advmod --> ADV
# frequently --> advmod --> ADV
# altered --> ccomp --> VERB
# in --> prep --> ADP
# over --> prep --> ADP
# expressing --> pcomp --> VERB
# miR-146a.cortical --> compound --> PRON
# samples --> dobj --> NOUN
# from --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# and --> cc --> CCONJ
# give --> conj --> VERB
# important --> amod --> ADJ
#   --> dep --> SPACE
# P09.71C --> dobj --> PROPN
# L. --> nsubj --> PROPN
# Ruaud1,2,D.HÃ --> dep --> VERB
# © --> punct --> PROPN
# ron2,3,4,H.Maurey5,C.The --> amod --> ADJ
# effect --> nsubj --> NOUN
# of --> prep --> ADP
# premutation --> compound --> NOUN
# status --> compound --> NOUN
# - --> punct --> PUNCT
# Group --> compound --> PROPN
# III --> pobj --> PROPN
# ( --> punct --> PUNCT
# 17 --> nummod --> NUM
# patients --> appos --> NOUN
# ) --> punct --> PUNCT
# from --> prep --> ADP
# our --> poss --> PRON
# center --> pobj --> NOUN
# exhibiting --> pcomp --> VERB
# a --> det --> DET
# severe --> dobj --> ADJ
# on --> prep --> ADP
# physical --> amod --> ADJ
# phenotype --> pobj --> NOUN
# was --> ROOT --> AUX
# less --> advmod --> ADV
# evident --> acomp --> ADJ
# and --> cc --> CCONJ
# concerned --> conj --> VERB
# only --> advmod --> ADV
# some --> det --> DET
# encephalopathy --> attr --> NOUN
# with --> prep --> ADP
# autistic --> amod --> ADJ
# behaviour --> pobj --> NOUN
# . --> punct --> PUNCT
# Many --> amod --> ADJ
# rare --> amod --> ADJ
# Copy --> compound --> PROPN
# Number --> compound --> PROPN
# Variants --> nsubjpass --> PROPN
# ( --> punct --> PUNCT
# CNVs --> appos --> PROPN
# ) --> punct --> PUNCT
# that --> nsubj --> PRON
# harbor --> relcl --> VERB
# Prevalence --> dobj --> NOUN
# of --> prep --> ADP
# fragile --> amod --> ADJ
# X --> compound --> NOUN
# syndrome --> pobj --> NOUN
# in --> prep --> ADP
# non --> amod --> ADJ
# - --> amod --> ADJ
# syndromic --> amod --> ADJ
# autistic --> amod --> ADJ
# small --> amod --> ADJ
# genomic --> amod --> ADJ
# deletions --> pobj --> NOUN
# and --> cc --> CCONJ
# insertions --> conj --> NOUN
# have --> aux --> AUX
# been --> auxpass --> AUX
# described --> ROOT --> VERB
# in --> prep --> ADP
# the --> det --> DET
# children --> pobj --> NOUN
# in --> prep --> ADP
# western --> amod --> ADJ
# saudi --> compound --> PROPN
# arabia --> compound --> PROPN
# autism --> compound --> NOUN
# spectrum --> compound --> NOUN
# disorders --> pobj --> NOUN
# ( --> punct --> PUNCT
# ASD).To --> nsubj --> PROPN
# identify --> parataxis --> VERB
# these --> det --> DET
# likely --> amod --> ADJ
# functional --> amod --> ADJ
# M. --> compound --> PROPN
# M. --> compound --> PROPN
# Alwasiyah1 --> dobj --> PROPN
# , --> punct --> PUNCT
# C. --> compound --> PROPN
# Trujillo2 --> appos --> NOUN
# ; --> punct --> PUNCT
# elements --> appos --> NOUN
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# combined --> parataxis --> VERB
# three --> dobj --> NUM
# previously --> advmod --> ADV
# published --> acl --> VERB
# large --> amod --> ADJ
# cohorts --> dobj --> NOUN
# 1Aziziah --> compound --> PROPN
# Maternity --> appos --> PROPN
# & --> cc --> CCONJ
# Children --> compound --> PROPN
# Hospital --> conj --> PROPN
# , --> punct --> PUNCT
# Jeddah --> conj --> PROPN
# , --> punct --> PUNCT
# Saudi --> compound --> PROPN
# Arabia --> conj --> PROPN
# , --> punct --> PUNCT
# 2Dr --> appos --> NUM
# Erfan --> appos --> PROPN
# & --> cc --> CCONJ
# of --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# with --> prep --> ADP
# a --> det --> DET
# large --> amod --> ADJ
# number --> pobj --> NOUN
# of --> prep --> ADP
# controls --> pobj --> NOUN
# to --> aux --> PART
# analyze --> advcl --> VERB
# over --> prep --> ADP
# Bagedo --> compound --> PROPN
# Hospital --> pobj --> PROPN
# , --> punct --> PUNCT
# Jeddah --> conj --> PROPN
# , --> punct --> PUNCT
# Saudi --> compound --> PROPN
# Arabia --> appos --> PROPN
# . --> punct --> PUNCT
# In --> prep --> ADP
# all --> pobj --> PRON
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# uncovered --> ROOT --> VERB
# the --> det --> DET
# literature --> dobj --> NOUN
# that --> dobj --> PRON
# FXS --> nsubj --> PROPN
# in --> prep --> ADP
# the --> det --> DET
# autistic --> amod --> ADJ
# populati5 --> pobj --> PROPN
# % --> npadvmod --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# that --> mark --> SCONJ
# 30 --> nummod --> NUM
# % --> conj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# 275 --> nummod --> NUM
# statistically --> advmod --> ADV
# significant --> amod --> ADJ
# distinct --> amod --> ADJ
# copy --> compound --> NOUN
# number --> nmod --> NOUN
# variable --> amod --> ADJ
# regions --> pobj --> NOUN
# . --> punct --> PUNCT
# Among --> prep --> ADP
# the --> det --> DET
# remaining --> amod --> VERB
# patients --> pobj --> NOUN
# with --> prep --> ADP
# FXS --> pobj --> PROPN
# , --> punct --> PUNCT
# 60 --> nummod --> NUM
# genes --> nsubjpass --> NOUN
# nearest --> prep --> ADP
# these --> det --> DET
# robust --> amod --> ADJ
# CNVRs --> pobj --> NOUN
# are --> auxpass --> AUX
# most --> advmod --> ADV
# enriched --> advcl --> ADJ
# in --> prep --> ADP
# gene --> pobj --> NOUN
# of --> prep --> ADP
# those --> pobj --> PRON
# who --> nsubj --> PRON
# do --> aux --> AUX
# not --> neg --> PART
# meet --> relcl --> VERB
# the --> det --> DET
# criteria --> dobj --> NOUN
# for --> prep --> ADP
# an --> det --> DET
# autism --> compound --> NOUN
# spectrum --> compound --> NOUN
# disorder --> compound --> NOUN
# networks --> pobj --> NOUN
# impacting --> acl --> VERB
# neurological --> amod --> ADJ
# disease --> dobj --> NOUN
# , --> punct --> PUNCT
# behavior --> conj --> NOUN
# and --> cc --> CCONJ
# developmental --> amod --> ADJ
# ( --> punct --> PUNCT
# ASD --> nmod --> PROPN
# ) --> punct --> PUNCT
# diagnosis --> conj --> NOUN
# , --> punct --> PUNCT
# the --> det --> DET
# majority --> nsubj --> NOUN
# have --> ROOT --> VERB
# one --> nummod --> NUM
# or --> cc --> CCONJ
# more --> conj --> ADJ
# autistic --> amod --> ADJ
# features --> dobj --> NOUN
# , --> punct --> PUNCT
# such --> amod --> ADJ
# disorder --> appos --> NOUN
# . --> punct --> PUNCT
# Asperger --> compound --> PROPN
# syndrome --> nsubjpass --> NOUN
# ( --> punct --> PUNCT
# AS --> appos --> PROPN
# ) --> punct --> PUNCT
# was --> auxpass --> AUX
# first --> advmod --> ADV
# described --> ROOT --> VERB
# in --> prep --> ADP
# 1944 --> pobj --> NUM
# by --> agent --> ADP
# a --> det --> DET
# Viennese --> nmod --> ADJ
# physi- --> dep --> NOUN
# O. --> compound --> PROPN
# T. --> compound --> PROPN
# Njajou --> pobj --> PROPN
# , --> punct --> PUNCT
# N. --> compound --> PROPN
# Vaessen --> appos --> PROPN
# , --> punct --> PUNCT
# B. --> compound --> PROPN
# Berghuis --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# H. --> compound --> PROPN
# Breuning --> appos --> PROPN
# , --> punct --> PUNCT
# W. --> compound --> PROPN
# P. --> compound --> PROPN
# T. --> compound --> PROPN
# Rutten --> appos --> PROPN
# , --> punct --> PUNCT
# P. --> compound --> PROPN
# cian --> amod --> ADJ
# Hans --> compound --> PROPN
# Asperger --> appos --> PROPN
# who --> nsubj --> PRON
# reported --> relcl --> VERB
# a --> det --> DET
# group --> dobj --> NOUN
# of --> prep --> ADP
# boys --> pobj --> NOUN
# with --> prep --> ADP
# autistic --> amod --> ADJ
# psychopa- --> compound --> PROPN
# J. --> compound --> PROPN
# L. --> compound --> PROPN
# Snijders --> pobj --> PROPN
# , --> punct --> PUNCT
# J. --> compound --> PROPN
# Houwing --> compound --> PROPN
# - --> punct --> PUNCT
# Duistermaat --> conj --> PROPN
# , --> punct --> PUNCT
# A. --> compound --> NOUN
# Hofman --> appos --> PROPN
# , --> punct --> PUNCT
# B.phenotype --> appos --> NOUN
# is --> auxpass --> AUX
# associated --> relcl --> VERB
# with --> prep --> ADP
# intellectual --> amod --> ADJ
# disability --> pobj --> NOUN
# , --> punct --> PUNCT
# poor --> amod --> ADJ
# Conclusion --> appos --> NOUN
# : --> punct --> PUNCT
# It --> nsubj --> PRON
# is --> acl --> AUX
# important --> acomp --> ADJ
# to --> aux --> PART
# consider --> xcomp --> VERB
# mutations --> dobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# speech --> pobj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# traits --> conj --> NOUN
# , --> punct --> PUNCT
# distinct --> amod --> ADJ
# face --> nmod --> NOUN
# and --> cc --> CCONJ
# signiï¬cant --> nmod --> NOUN
# feeding --> amod --> VERB
# PI3K --> compound --> NOUN
# - --> punct --> PUNCT
# AKT --> compound --> PROPN
# - --> punct --> PUNCT
# mTOR --> conj --> PROPN
# pathway --> conj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# evaluation --> pobj --> NOUN
# of --> prep --> ADP
# children --> compound --> NOUN
# difï¬culties --> pobj --> NOUN
# compatible --> amod --> ADJ
# with --> prep --> ADP
# our --> poss --> PRON
# patient --> amod --> ADJ
# phenotype --> pobj --> NOUN
# . --> punct --> PUNCT
# This --> det --> DET
# clinical --> amod --> ADJ
# picture --> nsubjpass --> NOUN
# is --> auxpass --> AUX
# compared --> ROOT --> VERB
# to --> prep --> ADP
# the --> det --> DET
# published --> amod --> VERB
# pheno- --> dep --> PROPN
# Modelling --> compound --> PROPN
# ARX --> dep --> PROPN
# and --> cc --> CCONJ
# KDM5C --> conj --> PROPN
# defects --> pobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# identical --> amod --> ADJ
# stem --> compound --> NOUN
# types --> pobj --> NOUN
# of --> prep --> ADP
# patients --> pobj --> NOUN
# with --> prep --> ADP
# MYT1L --> compound --> PROPN
# point --> compound --> NOUN
# mutations --> pobj --> NOUN
# , --> punct --> PUNCT
# with --> prep --> ADP
# cell --> compound --> NOUN
# line --> pobj --> NOUN
# might --> aux --> AUX
# allow --> advcl --> VERB
# us --> nsubj --> PRON
# to --> aux --> PART
# assess --> ccomp --> VERB
# the --> det --> DET
# degree --> dobj --> NOUN
# of --> prep --> ADP
# molecularAbstractsfromthe50thEuropeanSocietyofHumanGeneticsConference --> pobj --> PROPN
# : --> punct --> PUNCT
# ... --> punct --> PUNCT
# 351 --> nummod --> NUM
# convergencecausedbyaltereddosageofthesetwodisease- --> nmod --> NOUN
# unexplainedneurodevelopmentaldisorderscharacterizedby --> npadvmod --> PROPN
# related --> amod --> VERB
# genes --> appos --> NOUN
# and --> cc --> CCONJ
# the --> conj --> PRON
# in --> prep --> ADP
# vivo --> amod --> ADJ
# validation --> pobj --> NOUN
# of --> prep --> ADP
# potential --> amod --> ADJ
# drugs --> pobj --> NOUN
# intellectual --> amod --> ADJ
# disability --> appos --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# traits --> nsubj --> NOUN
# and --> cc --> CCONJ
# clinical --> amod --> ADJ
# features --> conj --> NOUN
# of --> prep --> ADP
# that --> pobj --> PRON
# could --> aux --> AUX
# compensate --> conj --> VERB
# KDM5C --> compound --> PROPN
# - --> punct --> PUNCT
# H3K4me3 --> nmod --> PROPN
# deregulation.âClassicalâ --> punct --> PROPN
# phenotype --> npadvmod --> NOUN
# inclu- --> amod --> ADJ
# vements --> dobj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# , --> punct --> PUNCT
# gait --> amod --> ADJ
# apraxia --> conj --> NOUN
# , --> punct --> PUNCT
# breathing --> compound --> NOUN
# anomalies --> conj --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# seizures --> conj --> NOUN
# . --> punct --> PUNCT
# Skeletal --> amod --> ADJ
# fea- --> npadvmod --> X
# with --> prep --> ADP
# or --> cc --> CCONJ
# without --> conj --> ADP
# autistic --> amod --> ADJ
# traits --> pobj --> NOUN
# , --> punct --> PUNCT
# in --> prep --> ADP
# a --> det --> DET
# total --> pobj --> NOUN
# of --> prep --> ADP
# 12 --> nummod --> NUM
# individuals --> compound --> NOUN
# tures --> pobj --> NOUN
# included --> ROOT --> VERB
# rib --> compound --> NOUN
# abnormalities --> dobj --> NOUN
# ( --> punct --> PUNCT
# 2/4 --> appos --> NUM
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# abnormal --> amod --> ADJ
# vertebrae --> appos --> NOUN
# ( --> punct --> PUNCT
# twodenovoandtwoinheritedfromaffectedparents).Our --> prep --> ADP
# ( --> punct --> PUNCT
# 1/4 --> pobj --> NUM
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# Sprengel --> compound --> PROPN
# deformity --> dobj --> NOUN
# ( --> punct --> PUNCT
# 1/4 --> appos --> NUM
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# long --> advmod --> ADV
# hyperextensible --> amod --> NOUN
# ï¬n- --> npadvmod --> PROPN
# dataenlargedtheAUT --> punct --> PUNCT
# S2.067 --> npadvmod --> PROPN
# performed.with --> appos --> NOUN
# autistic --> amod --> ADJ
# features --> pobj --> NOUN
# , --> punct --> PUNCT
# Fragile --> amod --> ADJ
# X --> compound --> NOUN
# Syndrome --> conj --> PROPN
# ( --> punct --> PUNCT
# FXS --> appos --> PROPN
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# results --> conj --> NOUN
# fromf --> compound --> NOUN
# mthre1 --> compound --> NOUN
# gene --> compound --> NOUN
# silencing --> acl --> NOUN
# and --> cc --> CCONJ
# loss --> conj --> NOUN
# of --> prep --> ADP
# Fragile --> amod --> ADJ
# X --> compound --> PROPN
# Mental --> compound --> PROPN
# Retardation --> compound --> PROPN
# Protein --> pobj --> PROPN
# ( --> punct --> PUNCT
# FMRP).Common --> compound --> NOUN
# findings --> nsubj --> NOUN
# are --> ccomp --> AUX
# microceph- --> nmod --> NOUN
# tism --> attr --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# - --> punct --> PUNCT
# like --> amod --> ADJ
# behavior --> conj --> NOUN
# and --> cc --> CCONJ
# mild --> amod --> ADJ
# dysmorphic --> amod --> ADJ
# features --> conj --> NOUN
# .W. --> punct --> PUNCT
# Lissens1 --> nsubj --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# Seneca1 --> appos --> PROPN
# , --> punct --> PUNCT
# K. --> compound --> PROPN
# Keymolen1 --> appos --> PROPN
# , --> punct --> PUNCT
# I. --> compound --> PROPN
# Liebaers1 --> conj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Schmuth2 --> appos --> PROPN
# , --> punct --> PUNCT
# P. --> compound --> PROPN
# M. --> compound --> PROPN
# Elias3 --> appos --> PROPN
# , --> punct --> PUNCT
# We --> nsubj --> PRON
# examined --> parataxis --> VERB
# 6 --> nummod --> NUM
# siblings --> dobj --> NOUN
# of --> prep --> ADP
# which --> pobj --> PRON
# 3 --> nummod --> NUM
# males --> nsubj --> NOUN
# ( --> punct --> PUNCT
# ages --> appos --> NOUN
# 9 --> quantmod --> NUM
# - --> punct --> SYM
# 14 --> nummod --> NUM
# years --> appos --> NOUN
# ) --> punct --> PUNCT
# were --> ROOT --> AUX
# J. --> attr --> PROPN
# Hachem4,3 --> nummod --> SPACE
# ; --> punct --> PUNCT
# affected --> advcl --> VERB
# with --> prep --> ADP
# mental --> amod --> ADJ
# retardation --> pobj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# and --> cc --> CCONJ
# one --> nummod --> NUM
# female --> amod --> ADJ
# 1Center --> conj --> NOUN
# for --> prep --> ADP
# Medical --> compound --> PROPN
# Genetics --> pobj --> PROPN
# , --> punct --> PUNCT
# University --> compound --> PROPN
# Hospital --> compound --> PROPN
# Vrije --> compound --> PROPN
# Universiteit --> compound --> PROPN
# Brussel --> conj --> PROPN
# , --> punct --> PUNCT
# ( --> punct --> PUNCT
# 16 --> nummod --> NUM
# years --> appos --> NOUN
# ) --> punct --> PUNCT
# was --> auxpass --> AUX
# diagnosed --> conj --> VERB
# to --> aux --> PART
# have --> xcomp --> VERB
# behavioral --> amod --> ADJ
# problems --> dobj --> NOUN
# and --> cc --> CCONJ
# suspected --> amod --> VERB
# Brussels --> conj --> PROPN
# , --> punct --> PUNCT
# Belgium --> conj --> PROPN
# , --> punct --> PUNCT
# 2Dermatology --> conj --> NUM
# , --> punct --> PUNCT
# University --> conj --> PROPN
# of --> prep --> ADP
# Innsbruck --> pobj --> PROPN
# , --> punct --> PUNCT
# Innsbruck --> conj --> PROPN
# , --> punct --> PUNCT
# Austria --> conj --> PROPN
# , --> punct --> PUNCT
# mood --> compound --> NOUN
# disorder --> appos --> NOUN
# .The --> punct --> PRON
# familial --> amod --> ADJ
# co --> conj --> NOUN
# - --> dobj --> NOUN
# segregation --> dobj --> NOUN
# of --> prep --> ADP
# mental --> amod --> ADJ
# retardation --> pobj --> NOUN
# and --> cc --> CCONJ
# 3Dermatology --> compound --> PROPN
# Research --> conj --> PROPN
# , --> punct --> PUNCT
# UCSF --> appos --> PROPN
# , --> punct --> PUNCT
# San --> compound --> PROPN
# Francisco --> conj --> PROPN
# , --> punct --> PUNCT
# CA --> appos --> PROPN
# , --> punct --> PUNCT
# United --> compound --> PROPN
# States --> conj --> PROPN
# , --> punct --> PUNCT
# 4Dermatol- --> nummod --> NUM
# autistic --> amod --> ADJ
# features --> nsubj --> NOUN
# in --> prep --> ADP
# males --> pobj --> NOUN
# supported --> conj --> VERB
# an --> det --> DET
# X --> npadvmod --> NOUN
# linked --> amod --> VERB
# inheritance --> dobj --> NOUN
# .Later --> dep --> SPACE
# , --> punct --> PUNCT
# dysmorphic --> amod --> ADJ
# features --> conj --> NOUN
# , --> punct --> PUNCT
# body --> compound --> NOUN
# asymmetry --> conj --> NOUN
# , --> punct --> PUNCT
# increa- --> conj --> PROPN
# disability --> nsubj --> NOUN
# became --> conj --> VERB
# progressively --> advmod --> ADV
# obvious --> acomp --> ADJ
# and --> cc --> CCONJ
# was --> auxpass --> AUX
# associated --> conj --> VERB
# with --> prep --> ADP
# autistic --> amod --> ADJ
# sing --> pobj --> VERB
# linear --> amod --> ADJ
# pigmentation --> dobj --> NOUN
# on --> prep --> ADP
# the --> det --> DET
# arms --> pobj --> NOUN
# and --> cc --> CCONJ
# legs --> conj --> NOUN
# , --> punct --> PUNCT
# hyperopia --> conj --> NOUN
# , --> punct --> PUNCT
# strabismus --> conj --> NOUN
# and --> cc --> CCONJ
# behaviors --> conj --> NOUN
# in --> prep --> ADP
# eight --> nummod --> NUM
# patients --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# severity --> nsubj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# epilepsy --> compound --> NOUN
# motherâs --> compound --> NOUN
# CMA --> compound --> PROPN
# results --> pobj --> NOUN
# showed --> ccomp --> VERB
# maternal --> amod --> ADJ
# heterodisomy --> nsubj --> PROPN
# of --> prep --> ADP
# the --> det --> DET
# whole --> amod --> ADJ
# chromo- --> pobj --> NOUN
# did --> aux --> AUX
# not --> neg --> PART
# correlate --> ccomp --> VERB
# with --> prep --> ADP
# the --> det --> DET
# presence --> pobj --> NOUN
# of --> prep --> ADP
# autistic --> amod --> ADJ
# features --> pobj --> NOUN
# or --> cc --> CCONJ
# with --> conj --> ADP
# the --> det --> DET
# severity --> pobj --> NOUN
# some --> det --> DET
# 14.Objectives --> npadvmod --> NUM
# : --> punct --> PUNCT
# The --> det --> DET
# arginine --> compound --> ADJ
# vasopressin --> compound --> NOUN
# receptor --> compound --> NOUN
# 1A --> compound --> NOUN
# gene --> nsubjpass --> NOUN
# ( --> punct --> PUNCT
# AVPR1A --> appos --> NOUN
# ) --> punct --> PUNCT
# is --> auxpass --> AUX
# related --> amod --> VERB
#   --> dep --> SPACE
# P09.36 --> compound --> NOUN
# hasmoreseveredevelopmentdelayandshowsincontrastto --> nsubj --> NOUN
# Two --> nummod --> NUM
# families --> nsubj --> NOUN
# with --> prep --> ADP
# inherited --> amod --> VERB
# protein --> pobj --> NOUN
# truncating --> acl --> VERB
# CHD3 --> dobj --> PROPN
# her --> poss --> PRON
# sister --> compound --> NOUN
# microcephaly --> appos --> NOUN
# , --> punct --> PUNCT
# craniosynostosis --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# variants --> conj --> NOUN
# suggest --> ROOT --> VERB
# reduced --> amod --> VERB
# penetrance --> dobj --> NOUN
# in --> prep --> ADP
# Snijders --> pobj --> PROPN
# Blok- --> amod --> PROPN
# behaviour --> appos --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# boyâs --> compound --> NOUN
# father --> nsubj --> NOUN
# is --> ROOT --> AUX
# asymptomaticR.PP02 --> nmod --> PROPN
# .161 --> compound --> PROPN
# tazacker2 --> attr --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# Esmaeili --> compound --> PROPN
# Nieh2 --> conj --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# Abedini1 --> conj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Mohseni1 --> conj --> PROPN
# , --> punct --> PUNCT
# H. --> compound --> PROPN
# Darvish1 --> conj --> PROPN
# , --> punct --> PUNCT
# G. --> compound --> PROPN
# Bahrami --> conj --> PROPN
# A --> det --> DET
# complex --> amod --> ADJ
# chromosome --> compound --> NOUN
# 7q --> compound --> PROPN
# rearrangement --> attr --> NOUN
# identified --> acl --> VERB
# in --> prep --> ADP
# a --> det --> DET
# patient --> amod --> ADJ
# Monajemi1 --> pobj --> NOUN
# , --> punct --> PUNCT
# R. --> compound --> PROPN
# Vazifehmand1 --> appos --> PROPN
# , --> punct --> PUNCT
# F. --> compound --> PROPN
# Rakhshani3 --> conj --> PROPN
# , --> punct --> PUNCT
# A. --> compound --> PROPN
# Zadeh --> compound --> PROPN
# - --> punct --> PUNCT
# Vakili3 --> appos --> PROPN
# , --> punct --> PUNCT
# J. --> compound --> PROPN
# Oveisi3 --> conj --> PROPN
# , --> punct --> PUNCT
# A. --> appos --> NOUN
# with --> prep --> ADP
# mental --> amod --> ADJ
# retardation --> pobj --> NOUN
# , --> punct --> PUNCT
# anxiety --> compound --> NOUN
# disorder --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# Naghavi3 --> conj --> PROPN
# , --> punct --> PUNCT
# G. --> compound --> PROPN
# Mollashahi --> compound --> PROPN
# Sanatgar3 --> appos --> PROPN
# , --> punct --> PUNCT
# H. --> compound --> PROPN
# Ropers2 --> conj --> PROPN
# , --> punct --> PUNCT
# H. --> compound --> PROPN
# Najmabadi1 --> appos --> PROPN
# ; --> punct --> PUNCT
# J. --> compound --> PROPN
# G. --> compound --> PROPN
# Dauwerse --> appos --> PROPN
# , --> punct --> PUNCT
# C. --> compound --> PROPN
# A. --> compound --> NOUN
# L. --> compound --> PROPN
# Ruivenkamp --> appos --> PROPN
# , --> punct --> PUNCT
# K. --> compound --> PROPN
# B. --> compound --> PROPN
# M. --> compound --> PROPN
# Hansson --> appos --> PROPN
# , --> punct --> PUNCT
# D. --> compound --> PROPN
# J. --> compound --> PROPN
# M. --> compound --> PROPN
# Peters --> conj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# 1Genetics --> compound --> PROPN
# Research --> compound --> PROPN
# Center --> conj --> PROPN
# , --> punct --> PUNCT
# University --> nmod --> PROPN
# of --> prep --> ADP
# Social --> compound --> PROPN
# Welfare --> pobj --> PROPN
# and --> cc --> CCONJ
# Rehabilitation --> compound --> PROPN
# H. --> compound --> PROPN
# Breuning --> appos --> PROPN
# , --> punct --> PUNCT
# Y. --> compound --> PROPN
# Hilhorst --> compound --> PROPN
# - --> punct --> PUNCT
# Hofstee --> conj --> PROPN
# ; --> punct --> PUNCT
# Sciences --> conj --> PROPN
# , --> punct --> PUNCT
# Tehran --> conj --> PROPN
# , --> punct --> PUNCT
# Islamic --> compound --> PROPN
# Republic --> conj --> PROPN
# of --> prep --> ADP
# Iran --> pobj --> PROPN
# , --> punct --> PUNCT
# 2Max --> nummod --> NUM
# Planck --> compound --> PROPN
# Institute --> appos --> PROPN
# for --> prep --> ADP
# Molecular --> compound --> PROPN
# LUMC --> pobj --> PROPN
# , --> punct --> PUNCT
# Leiden --> conj --> PROPN
# , --> punct --> PUNCT
# The --> det --> DET
# Netherlands --> appos --> PROPN
# . --> punct --> PUNCT
# The --> det --> DET
# girl --> nsubj --> NOUN
# is --> ROOT --> AUX
# mentally --> advmod --> ADV
# retarded --> acomp --> VERB
# , --> punct --> PUNCT
# suffers --> conj --> VERB
# from --> prep --> ADP
# a --> det --> DET
# severe --> amod --> ADJ
# anxiety --> compound --> NOUN
# disorder --> pobj --> NOUN
# We --> nsubj --> PRON
# report --> relcl --> VERB
# three --> dobj --> NUM
# out --> prep --> ADP
# of --> prep --> ADP
# a --> det --> DET
# total --> pobj --> NOUN
# of --> prep --> ADP
# 50 --> nummod --> NUM
# Iranian --> amod --> ADJ
# consanguineous --> amod --> ADJ
# families --> pobj --> NOUN
# and --> cc --> CCONJ
# has --> conj --> VERB
# autistic --> amod --> ADJ
# features --> dobj --> NOUN
# .screen --> acomp --> NUM
# autistic --> amod --> ADJ
# patientâs --> nmod --> NOUN
# whole --> amod --> ADJ
# genome --> attr --> NOUN
# in --> prep --> ADP
# order --> pobj --> NOUN
# to --> aux --> PART
# investigate --> acl --> VERB
# new --> dobj --> ADJ
# Although --> mark --> SCONJ
# the --> det --> DET
# molecular --> amod --> ADJ
# basis --> nsubj --> NOUN
# of --> prep --> ADP
# this --> det --> DET
# disorder --> pobj --> NOUN
# has --> aux --> AUX
# not --> neg --> PART
# been --> advcl --> AUX
# totally --> advmod --> ADV
# dchromosomal --> acomp --> ADJ
# abberations.(Oxford --> compound --> PROPN
# Gene --> compound --> PROPN
# Technology --> dobj --> PROPN
# , --> punct --> PUNCT
# Oxford --> nmod --> PROPN
# , --> punct --> PUNCT
# UK --> nmod --> PROPN
# ) --> punct --> PUNCT
# microchips --> appos --> NOUN
# and --> cc --> CCONJ
# scanned --> conj --> VERB
# with --> prep --> ADP
# Agilent --> compound --> PROPN
# Microarray --> compound --> PROPN
# Scanner --> pobj --> NOUN
# ( --> punct --> PUNCT
# Agilent --> compound --> PROPN
# Technologies --> nsubjpass --> PROPN
# , --> punct --> PUNCT
# Palo --> compound --> PROPN
# Alto --> npadvmod --> PROPN
# , --> punct --> PUNCT
# CAP1 --> compound --> PROPN
#   --> dep --> SPACE
# autism --> compound --> NOUN
# spectrum --> compound --> NOUN
# disorder --> appos --> NOUN
# may --> aux --> AUX
# be --> auxpass --> AUX
# caused --> relcl --> VERB
# by --> agent --> ADP
# Conclusions --> pobj --> NOUN
# : --> punct --> PUNCT
# Because --> prep --> SCONJ
# of --> pcomp --> ADP
# an --> det --> DET
# etiologic --> amod --> ADJ
# heterogeneity --> pobj --> NOUN
# of --> prep --> ADP
# impaired --> amod --> ADJ
# gut --> compound --> NOUN
# motility --> pobj --> NOUN
# and --> cc --> CCONJ
# achalasia --> conj --> PROPN
# , --> punct --> PUNCT
# driven --> acl --> VERB
# by --> agent --> ADP
# FOX --> compound --> PROPN
# cause --> compound --> NOUN
# neurodegeneration --> pobj --> NOUN
# the --> det --> DET
# autistic --> amod --> ADJ
# spectrum --> appos --> NOUN
# . --> punct --> PUNCT
# De --> compound --> PROPN
# novo --> compound --> PROPN
# 7q --> compound --> PROPN
# deletion --> ROOT --> NOUN
# in --> prep --> ADP
# a --> det --> DET
# family --> pobj --> NOUN
# with --> prep --> ADP
# 16p --> compound --> PROPN
# duplication --> pobj --> NOUN
# , --> punct --> PUNCT
# autism --> conj --> NOUN
# and --> cc --> CCONJ
# We --> nsubj --> PRON
# report --> conj --> VERB
# two --> nummod --> NUM
# children --> dobj --> NOUN
# with --> prep --> ADP
# autistic --> amod --> ADJ
# behavior --> pobj --> NOUN
# and --> cc --> CCONJ
# mental --> amod --> ADJ
# retardation --> conj --> NOUN
# . --> punct --> PUNCT
# A --> det --> DET
# dramatic --> amod --> ADJ
# reorganization --> nsubjpass --> NOUN
# of --> prep --> ADP
# these --> det --> DET
# chromatin --> compound --> NOUN
# inter- --> pobj --> NOUN
# G. --> compound --> PROPN
# Di --> appos --> PROPN
# Fruscio1,2 --> npadvmod --> PROPN
# , --> punct --> PUNCT
# A. --> compound --> PROPN
# Schulz3 --> conj --> PROPN
# , --> punct --> PUNCT
# R. --> compound --> PROPN
# De --> compound --> PROPN
# Cegli1 --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Mutarelli1 --> conj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Savarese1,2 --> appos --> PROPN
# , --> punct --> PUNCT
# V. --> compound --> PROPN
# Singhmarwah1 --> appos --> PROPN
# , --> punct --> PUNCT
# acting --> compound --> VERB
# networks --> nsubjpass --> NOUN
# is --> auxpass --> AUX
# displayed --> ROOT --> VERB
# in --> prep --> ADP
# cells --> pobj --> NOUN
# of --> prep --> ADP
# carriers --> pobj --> NOUN
# of --> prep --> ADP
# 600 --> nummod --> NUM
# kb --> compound --> PROPN
# BL15 --> compound --> PROPN
#   --> dep --> SPACE
# encodes --> pobj --> VERB
# a --> det --> DET
# GTP- --> nmod --> PROPN
# variable --> amod --> ADJ
# associated --> amod --> VERB
# alteration --> dobj --> NOUN
# including --> prep --> VERB
# autistic --> amod --> ADJ
# behavior --> nmod --> NOUN
# binding --> amod --> VERB
# protein --> pobj --> NOUN
# that --> nsubj --> PRON
# regulates --> relcl --> VERB
# the --> det --> DET
# magnesium --> compound --> NOUN
# transporter --> dobj --> NOUN
# and --> cc --> CCONJ
# insulinopathy --> conj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# clinical --> amod --> ADJ
# phenotype --> nsubj --> NOUN
# and --> cc --> CCONJ
# the --> det --> DET
# variant --> conj --> NOUN
# co --> appos --> NOUN
# - --> appos --> NOUN
# segregate --> appos --> ADJ
# , --> punct --> PUNCT
# with --> prep --> ADP
# dation --> pobj --> NOUN
# ( --> punct --> PUNCT
# MR --> appos --> PROPN
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# spectral --> amod --> ADJ
# disorders --> conj --> NOUN
# ( --> punct --> PUNCT
# ASD).1Institute --> appos --> NOUN
# of --> prep --> ADP
# Human --> compound --> PROPN
# Genetics --> pobj --> PROPN
# , --> punct --> PUNCT
# Leipzig --> conj --> PROPN
# , --> punct --> PUNCT
# Germany --> conj --> PROPN
# , --> punct --> PUNCT
# 2Klinik --> appos --> PROPN
# fÃ¼r --> appos --> PROPN
# NeuropÃ¤diatrie --> compound --> PROPN
# und --> amod --> ADJ
# Behavioural --> amod --> ADJ
# problems --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# are --> ROOT --> AUX
# common --> acomp --> ADJ
# . --> punct --> PUNCT
# At --> ROOT --> ADP
# the --> det --> DET
# age --> pobj --> NOUN
# of --> prep --> ADP
# at2.5yearsofageduetomildintellectualdisability --> pobj --> PROPN
# , --> punct --> PUNCT
# autisticAbstractsfromthe50thEuropeanSocietyofHumanGeneticsConference --> appos --> NOUN
# : --> punct --> PUNCT
# ... --> punct --> PUNCT
# 485 --> nummod --> NUM
# behaviour --> pobj --> NOUN
# , --> punct --> PUNCT
# epilepsy --> appos --> NOUN
# , --> punct --> PUNCT
# macrocephaly --> advmod --> ADJ
# , --> punct --> PUNCT
# dysmorphic --> amod --> ADJ
# features --> conj --> NOUN
# revealed --> acl --> VERB
# mosaic --> amod --> ADJ
# karyotype --> dobj --> NOUN
# : --> punct --> PUNCT
# 47,XX --> nummod --> PROPN
# , --> punct --> PUNCT
# i(8)(p10)[18]/46,XX --> conj --> PRON
# andatrialseptaldefect --> appos --> NOUN
# . --> punct --> PUNCT
# Herfatherandyoungerbrotherhave --> ROOT --> PROPN
# [ --> punct --> PUNCT
# 82].resulted --> amod --> ADJ
# negative --> ROOT --> ADJ
# in --> prep --> ADP
# 57 --> nummod --> NUM
# patients --> pobj --> NOUN
# while --> prep --> SCONJ
# in --> prep --> ADP
# 38 --> nummod --> NUM
# at --> advmod --> ADV
# least --> advmod --> ADJ
# one --> nummod --> NUM
# rearrangement --> conj --> NOUN
# This --> det --> DET
# genomic --> amod --> ADJ
# lesion --> compound --> NOUN
# cosegregates --> appos --> NOUN
# with --> prep --> ADP
# BWS --> compound --> PROPN
# phenotype --> pobj --> NOUN
# and --> cc --> CCONJ
# IP03 --> compound --> PROPN
# .102 --> nmod --> NUM
# Developmental --> amod --> ADJ
# delay --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# in --> prep --> ADP
# a --> det --> DET
# girl --> pobj --> NOUN
# with --> prep --> ADP
# guidance --> pobj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# developing --> amod --> VERB
# neurons --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# findings --> nsubj --> NOUN
# in --> prep --> ADP
# this --> det --> DET
# study --> pobj --> NOUN
# imply --> ROOT --> VERB
# 45,X/46,X --> dobj --> NUM
# , --> punct --> PUNCT
# r(X --> npadvmod --> PROPN
# ) --> punct --> PUNCT
# that --> det --> PRON
# CNVs --> nsubjpass --> NOUN
# might --> aux --> AUX
# be --> auxpass --> AUX
# involved --> ccomp --> VERB
# in --> prep --> ADP
# this --> det --> DET
# specific --> amod --> ADJ
# type --> pobj --> NOUN
# of --> prep --> ADP
# RTT --> pobj --> PROPN
# ( --> punct --> PUNCT
# 4/12 --> nummod --> NUM
# patients --> appos --> NOUN
# ) --> punct --> PUNCT
# B. --> compound --> PROPN
# BarreÃ±a1 --> dobj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# L. --> compound --> PROPN
# Onaindia1 --> appos --> PROPN
# , --> punct --> PUNCT
# J. --> compound --> PROPN
# GarcÃ­a1 --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# FiaÃ±o1 --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# A. --> compound --> NOUN
# Tapia1 --> appos --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# J. --> compound --> PROPN
# Angulo1 --> appos --> PROPN
# , --> punct --> PUNCT
# rather --> advmod --> ADV
# than --> cc --> ADP
# MEC.10 --> compound --> PRON
# postnatal --> compound --> ADJ
# microcephaly --> conj --> NOUN
# , --> punct --> PUNCT
# epilepsy --> conj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# behavior --> nsubj --> NOUN
# includ- --> relcl --> VERB
# Deletion --> compound --> NOUN
# 7q31.2q31.31 --> dobj --> PROPN
# segregating --> acl --> VERB
# in --> prep --> ADP
# a --> det --> DET
# family --> pobj --> NOUN
# with --> prep --> ADP
# ing --> amod --> VERB
# striking --> amod --> ADJ
# bruxism --> pobj --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# unspeciï¬c --> conj --> NOUN
# dysmorphic --> amod --> ADJ
# features --> dobj --> NOUN
# . --> punct --> PUNCT
# He --> compound --> PRON
# Margarita --> compound --> PROPN
# MartÃ­nez --> compound --> PROPN
# - --> punct --> PUNCT
# Atienza1 --> nsubjpass --> PROPN
# , --> punct --> PUNCT
# Susana --> compound --> PROPN
# GarcÃ­a --> compound --> PROPN
# - --> punct --> PUNCT
# Linares2 --> appos --> PROPN
# , --> punct --> PUNCT
# Antonio --> nsubjpass --> PROPN
# was --> auxpass --> AUX
# referred --> ROOT --> VERB
# to --> prep --> ADP
# genetic --> amod --> ADJ
# evaluation --> pobj --> NOUN
# because --> prep --> SCONJ
# of --> pcomp --> ADP
# the --> det --> DET
# mental --> amod --> ADJ
# Miguel --> compound --> PROPN
# Poyatos --> compound --> PROPN
# - --> punct --> PUNCT
# AndÃºjar2 --> pobj --> PROPN
# , --> punct --> PUNCT
# Irene --> compound --> PROPN
# SofÃ­a --> compound --> PROPN
# Machado --> compound --> PROPN
# - --> punct --> PUNCT
# Casas2 --> ccomp --> PROPN
# , --> punct --> PUNCT
# Susana --> compound --> PROPN
# retardation --> conj --> NOUN
# , --> punct --> PUNCT
# hypotonia --> conj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# . --> punct --> PUNCT
# Another --> det --> DET
# PM09.014 --> nsubjpass --> PROPN
# 12 --> nummod --> NUM
# % --> nsubjpass --> NOUN
# of --> prep --> ADP
# cases --> pobj --> NOUN
# were --> auxpass --> AUX
# probably --> advmod --> ADV
# solved --> ROOT --> VERB
# unless --> mark --> SCONJ
# the --> det --> DET
# segregation --> nmod --> NOUN
# ( --> punct --> PUNCT
# not --> neg --> PART
# completed --> acl --> VERB
# ) --> punct --> PUNCT
# CNVs --> nsubj --> NOUN
# in --> prep --> ADP
# the --> det --> DET
# group --> pobj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# patients --> pobj --> NOUN
# with --> prep --> ADP
# autistic --> amod --> ADJ
# spectrum --> compound --> NOUN
# disorders --> pobj --> NOUN
# yields --> advcl --> VERB
# controversial --> amod --> ADJ
# results --> dobj --> NOUN
# ( --> punct --> PUNCT
# 13 --> appos --> NUM
# with --> prep --> ADP
# onset --> pobj --> NOUN
# before --> advmod --> ADV
# , --> punct --> PUNCT
# 3 --> npadvmod --> NUM
# after --> prep --> ADP
# 40 --> nummod --> NUM
# ...
# at --> prep --> ADP
# a --> det --> DET
# distance --> pobj --> NOUN
# of --> prep --> ADP
# about --> advmod --> ADV
# 1 --> nummod --> NUM
# Mb --> pobj --> PROPN
# from --> prep --> ADP
# A --> det --> DET
# possible --> amod --> ADJ
# explanation --> pobj --> NOUN
# for --> prep --> ADP
# the --> det --> DET
# autistic --> amod --> ADJ
# regression --> pobj --> NOUN
# might --> aux --> AUX
# be --> advcl --> AUX
# the --> det --> DET
# tendency --> attr --> NOUN
# each --> det --> DET
# other --> advmod --> ADJ
# , --> punct --> PUNCT
# were --> auxpass --> AUX
# not --> neg --> PART
# included --> ROOT --> VERB
# in --> prep --> ADP
# the --> det --> DET
# duplication --> compound --> NOUN
# interval --> pobj --> NOUN
# .Many --> compound --> PROPN
# rare --> amod --> ADJ
# Copy --> compound --> PROPN
# Number --> compound --> PROPN
# Variants --> nsubjpass --> PROPN
# ( --> punct --> PUNCT
# CNVs --> appos --> PROPN
# ) --> punct --> PUNCT
# that --> nsubj --> PRON
# harbor --> relcl --> VERB
# Prevalence --> dobj --> NOUN
# of --> prep --> ADP
# fragile --> amod --> ADJ
# X --> compound --> NOUN
# syndrome --> pobj --> NOUN
# in --> prep --> ADP
# non --> amod --> ADJ
# - --> amod --> ADJ
# syndromic --> amod --> ADJ
# autistic --> amod --> ADJ
# small --> amod --> ADJ
# genomic --> amod --> ADJ
# deletions --> pobj --> NOUN
# and --> cc --> CCONJ
# insertions --> conj --> NOUN
# have --> aux --> AUX
# been --> auxpass --> AUX
# described --> conj --> VERB
# in --> prep --> ADP
# the --> det --> DET
# children --> pobj --> NOUN
# in --> prep --> ADP
# western --> amod --> ADJ
# saudi --> compound --> PROPN
# arabia --> compound --> PROPN
# autism --> compound --> NOUN
# spectrum --> compound --> NOUN
# disorders --> pobj --> NOUN
# ( --> punct --> PUNCT
# ASD).To --> nsubj --> PROPN
# identify --> parataxis --> VERB
# these --> det --> DET
# likely --> amod --> ADJ
# functional --> amod --> ADJ
# M. --> compound --> PROPN
# M. --> compound --> PROPN
# Alwasiyah1 --> dobj --> PROPN
# , --> punct --> PUNCT
# C. --> compound --> PROPN
# Trujillo2 --> appos --> NOUN
# ; --> punct --> PUNCT
# elements --> appos --> NOUN
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# combined --> parataxis --> VERB
# three --> dobj --> NUM
# previously --> advmod --> ADV
# published --> acl --> VERB
# large --> amod --> ADJ
# cohorts --> dobj --> NOUN
# 1Aziziah --> compound --> PROPN
# Maternity --> appos --> PROPN
# & --> cc --> CCONJ
# Children --> compound --> PROPN
# Hospital --> conj --> PROPN
# , --> punct --> PUNCT
# Jeddah --> conj --> PROPN
# , --> punct --> PUNCT
# Saudi --> compound --> PROPN
# Arabia --> conj --> PROPN
# , --> punct --> PUNCT
# 2Dr --> appos --> NUM
# Erfan --> appos --> PROPN
# & --> cc --> CCONJ
# of --> prep --> ADP
# autistic --> amod --> ADJ
# patients --> pobj --> NOUN
# with --> prep --> ADP
# a --> det --> DET
# large --> amod --> ADJ
# number --> pobj --> NOUN
# of --> prep --> ADP
# controls --> pobj --> NOUN
# to --> aux --> PART
# analyze --> advcl --> VERB
# over --> prep --> ADP
# Bagedo --> compound --> PROPN
# Hospital --> pobj --> PROPN
# , --> punct --> PUNCT
# Jeddah --> conj --> PROPN
# , --> punct --> PUNCT
# Saudi --> compound --> PROPN
# Arabia --> appos --> PROPN
# . --> punct --> PUNCT
# In --> prep --> ADP
# all --> pobj --> PRON
# , --> punct --> PUNCT
# we --> nsubj --> PRON
# uncovered --> ROOT --> VERB
# the --> det --> DET
# literature --> dobj --> NOUN
# that --> dobj --> PRON
# FXS --> nsubj --> PROPN
# in --> prep --> ADP
# the --> det --> DET
# autistic --> amod --> ADJ
# populati5 --> pobj --> PROPN
# % --> npadvmod --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# that --> mark --> SCONJ
# 30 --> nummod --> NUM
# % --> conj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# 275 --> nummod --> NUM
# statistically --> advmod --> ADV
# significant --> amod --> ADJ
# distinct --> amod --> ADJ
# copy --> compound --> NOUN
# number --> nmod --> NOUN
# variable --> amod --> ADJ
# regions --> pobj --> NOUN
# . --> punct --> PUNCT
# Among --> prep --> ADP
# the --> det --> DET
# remaining --> amod --> VERB
# patients --> pobj --> NOUN
# with --> prep --> ADP
# FXS --> pobj --> PROPN
# , --> punct --> PUNCT
# 60 --> nummod --> NUM
# genes --> nsubjpass --> NOUN
# nearest --> prep --> ADP
# these --> det --> DET
# robust --> amod --> ADJ
# CNVRs --> pobj --> NOUN
# are --> auxpass --> AUX
# most --> advmod --> ADV
# enriched --> advcl --> ADJ
# in --> prep --> ADP
# gene --> pobj --> NOUN
# of --> prep --> ADP
# those --> pobj --> PRON
# who --> nsubj --> PRON
# do --> aux --> AUX
# not --> neg --> PART
# meet --> relcl --> VERB
# the --> det --> DET
# criteria --> dobj --> NOUN
# for --> prep --> ADP
# an --> det --> DET
# autism --> compound --> NOUN
# spectrum --> compound --> NOUN
# disorder --> compound --> NOUN
# networks --> pobj --> NOUN
# impacting --> acl --> VERB
# neurological --> amod --> ADJ
# disease --> dobj --> NOUN
# , --> punct --> PUNCT
# behavior --> conj --> NOUN
# and --> cc --> CCONJ
# developmental --> amod --> ADJ
# ( --> punct --> PUNCT
# ASD --> nmod --> PROPN
# ) --> punct --> PUNCT
# diagnosis --> conj --> NOUN
# , --> punct --> PUNCT
# the --> det --> DET
# majority --> nsubj --> NOUN
# have --> ROOT --> VERB
# one --> nummod --> NUM
# or --> cc --> CCONJ
# more --> conj --> ADJ
# autistic --> amod --> ADJ
# features --> dobj --> NOUN
# , --> punct --> PUNCT
# such --> amod --> ADJ
# disorder --> appos --> NOUN
# . --> punct --> PUNCT
# Besides --> ROOT --> SCONJ
# regulating --> pcomp --> VERB
# the --> det --> DET
# activity --> dobj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# intellectual --> amod --> ADJ
# impairment --> pobj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# features --> conj --> NOUN
# , --> punct --> PUNCT
# macrocephaly --> amod --> ADJ
# translational --> amod --> ADJ
# regulators --> conj --> NOUN
# P.031 --> compound --> PROPN
# resonance --> compound --> NOUN
# imaging --> compound --> NOUN
# scans --> nsubjpass --> NOUN
# were --> auxpass --> AUX
# acquired --> ROOT --> VERB
# from --> prep --> ADP
# 6 --> nummod --> NUM
# ASPM --> npadvmod --> PROPN
# - --> punct --> PUNCT
# related --> amod --> VERB
# patients --> pobj --> NOUN
# . --> punct --> PUNCT
# A --> det --> DET
# new --> amod --> ADJ
# clinical --> amod --> ADJ
# picture --> ROOT --> NOUN
# with --> prep --> ADP
# hypopigmented --> amod --> ADJ
# hair --> pobj --> NOUN
# , --> punct --> PUNCT
# children --> appos --> NOUN
# with --> prep --> ADP
# this --> det --> DET
# phenotype --> pobj --> NOUN
# and --> cc --> CCONJ
# those --> conj --> PRON
# with --> prep --> ADP
# a --> det --> DET
# microdeletion --> pobj --> NOUN
# in --> prep --> ADP
# chromo- --> compound --> PROPN
# microcephaly --> pobj --> NOUN
# , --> punct --> PUNCT
# motor --> npadvmod --> NOUN
# - --> punct --> PUNCT
# mental --> amod --> ADJ
# retardation --> conj --> NOUN
# and --> cc --> CCONJ
# renal --> amod --> ADJ
# anomalies --> conj --> NOUN
# some --> det --> DET
# 22q11 --> appos --> NUM
# , --> punct --> PUNCT
# especially --> advmod --> ADV
# those --> appos --> PRON
# with --> prep --> ADP
# mental --> amod --> ADJ
# retardation --> pobj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# fea- --> conj --> PROPN
# A. --> ROOT --> PROPN
# Aykut --> nsubjpass --> PROPN
# , --> punct --> PUNCT
# A. --> compound --> PROPN
# Akarslan --> appos --> PROPN
# , --> punct --> PUNCT
# B. --> compound --> PROPN
# Durmaz --> appos --> PROPN
# , --> punct --> PUNCT
# F. --> compound --> PROPN
# Tuzun --> appos --> PROPN
# , --> punct --> PUNCT
# O. --> compound --> PROPN
# Cogulu --> appos --> PROPN
# , --> punct --> PUNCT
# F. --> compound --> PROPN
# Ozkinay --> appos --> PROPN
# ; --> punct --> PUNCT
# tures --> appos --> NOUN
# , --> punct --> PUNCT
# should --> aux --> AUX
# be --> auxpass --> AUX
# tested --> ROOT --> VERB
# for --> prep --> ADP
# hyperprolinemia --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# boy --> nsubjpass --> NOUN
# was --> auxpass --> AUX
# referred --> ROOT --> VERB
# for --> prep --> ADP
# global --> amod --> ADJ
# intellectual --> pobj --> ADJ
# disabili- --> punct --> PUNCT
# The --> det --> DET
# clinical --> amod --> ADJ
# phenotype --> ROOT --> NOUN
# of --> prep --> ADP
# 3q29 --> nummod --> NUM
# microdeletion --> pobj --> NOUN
# and --> cc --> CCONJ
# 3q29 --> compound --> NUM
# ty --> conj --> NOUN
# with --> prep --> ADP
# very --> advmod --> ADV
# limited --> amod --> ADJ
# speech --> compound --> NOUN
# capabilities --> pobj --> NOUN
# and --> cc --> CCONJ
# autistic --> amod --> ADJ
# traits --> conj --> NOUN
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# reviewed --> ROOT --> VERB
# and --> cc --> CCONJ
# reported --> conj --> VERB
# the --> det --> DET
# genotype --> nmod --> NOUN
# / --> punct --> SYM
# phenotype --> compound --> NOUN
# ly --> dobj --> NOUN
# and --> cc --> CCONJ
# behavior --> compound --> NOUN
# abnormalities --> conj --> NOUN
# of --> prep --> ADP
# the --> det --> DET
# autistic --> amod --> ADJ
# spectrum --> pobj --> NOUN
# . --> punct --> PUNCT
# The --> det --> DET
# manifestations --> ROOT --> NOUN
# of --> prep --> ADP
# thedisorderoccur --> amod --> ADJ
# primarilyin --> pobj --> NOUN
# sent --> acl --> VERB
# an8.5yearsoldboy --> dep --> ADJ
# , --> punct --> PUNCT
# withintractableepilepsy --> conj --> ADJ
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# theadrenalcortex --> appos --> NOUN
# , --> punct --> PUNCT
# themyelinofthecentralnervoussystem --> conj --> PROPN
# , --> punct --> PUNCT
# spectrum --> compound --> NOUN
# disorder --> conj --> NOUN
# ( --> punct --> PUNCT
# ASD --> appos --> PROPN
# ) --> punct --> PUNCT
# , --> punct --> PUNCT
# hypotonia --> conj --> NOUN
# during --> prep --> ADP
# infancy --> pobj --> NOUN
# , --> punct --> PUNCT
# stra- --> conj --> PROPN
# andtheLeydigcellsofthetestes --> dep --> PROPN
# . --> punct --> PUNCT
# Adrenoleukodystrophyis --> compound --> PROPN
# bismus --> nsubj --> PROPN
# and --> cc --> CCONJ
# behavioral --> amod --> ADJ
# problems.4Department --> conj --> NOUN
# of --> prep --> ADP
# Clinical --> compound --> PROPN
# Genetics --> pobj --> PROPN
# , --> punct --> PUNCT
# Aichi --> compound --> PROPN
# Developmental --> compound --> PROPN
# Clinical --> compound --> PROPN
# County --> compound --> PROPN
# Emergency --> compound --> PROPN
# Hospital --> conj --> PROPN
# , --> punct --> PUNCT
# Targu --> compound --> PROPN
# Mures --> conj --> PROPN
# , --> punct --> PUNCT
# Disability --> compound --> PROPN
# Center --> compound --> PROPN
# Central --> compound --> PROPN
# Hospital --> conj --> PROPN
# , --> punct --> PUNCT
# Kasugai --> conj --> PROPN
# , --> punct --> PUNCT
# Japan --> conj --> PROPN
# , --> punct --> PUNCT
# 5Cen- --> npadvmod --> NUM
# Romania --> compound --> PROPN
# ter --> appos --> PROPN
# for --> prep --> ADP
# Medical --> compound --> PROPN
# Genetics --> pobj --> PROPN
# , --> punct --> PUNCT
# Keio --> compound --> PROPN
# University --> compound --> PROPN
# School --> conj --> PROPN
# of --> prep --> ADP
# Medicine --> pobj --> PROPN
# , --> punct --> PUNCT
# Tokyo --> npadvmod --> PROPN
# , --> punct --> PUNCT
# Japan --> compound --> PROPN
# Craniosynostosis --> nsubj --> PROPN
# represents --> csubj --> VERB
# a --> det --> DET
# premature --> amod --> ADJ
# fusion --> dobj --> NOUN
# of --> prep --> ADP
# one --> pobj --> NUM
# or --> cc --> CCONJ
# morecranialsuturesleadingtosecondarydistortionofskull --> conj --> ADJ
# Menke --> compound --> PROPN
# - --> punct --> PUNCT
# Hennekam --> compound --> PROPN
# syndrome-1 --> dobj --> PROPN
# ( --> punct --> PUNCT
# MKHK1 --> appos --> PROPN
# ) --> punct --> PUNCT
# is --> ROOT --> AUX
# a --> det --> DET
# congenital --> amod --> ADJ
# shape --> attr --> NOUN
# resulting --> acl --> VERB
# in --> prep --> ADP
# skull --> compound --> NOUN
# deformities --> pobj --> NOUN
# with --> prep --> ADP
# a --> det --> DET
# variable --> amod --> ADJ
# pre- --> amod --> NOUN
# disordercharacterizedbyvariableimpairmentofintellectual --> amod --> ADJ
# sentation --> pobj --> NOUN
# . --> punct --> PUNCT
# Craniosynostosismayoccurinanisolatedsetting --> amod --> VERB
# development --> ROOT --> NOUN
# , --> punct --> PUNCT
# feeding --> amod --> VERB
# difï¬culties --> conj --> NOUN
# , --> punct --> PUNCT
# autistic --> amod --> ADJ
# behavior --> conj --> NOUN
# , --> punct --> PUNCT
# hearing --> acl --> VERB
# oraspartofasyndrome --> dobj --> PROPN
# . --> punct --> PUNCT
# FGFR2,FGFR3,FGFR1,TWIST1 --> ROOT --> NUM
# impairment --> nmod --> NOUN
# , --> punct --> PUNCT
# short --> amod --> ADJ
# stature --> nsubj --> NOUN
# , --> punct --> PUNCT
# microcephaly --> nmod --> NOUN
# , --> punct --> PUNCT
# and --> cc --> CCONJ
# facial --> amod --> ADJ
# dys- --> nmod --> NOUN
# and --> cc --> CCONJ
# EFNB --> conj --> PROPN
# genes --> appos --> NOUN
# are --> ROOT --> AUX
# major --> amod --> ADJ
# causative --> amod --> ADJ
# genes --> attr --> NOUN
# of --> prep --> ADP
# genetic --> amod --> ADJ
# morphisms --> pobj --> NOUN
# [ --> punct --> PUNCT
# Menke --> nmod --> PROPN
# et --> nmod --> X
# al --> dep --> PROPN
# . --> appos --> PROPN
# , --> punct --> PUNCT
# 2016 --> appos --> NUM
# ; --> punct --> PUNCT
# Menke --> compound --> PROPN
# et --> compound --> X
# al --> npadvmod --> PROPN
# . --> appos --> PROPN
# , --> punct --> PUNCT
# 2018].tures --> nummod --> NUM
# includedysmorphic --> amod --> ADJ
# features --> nsubjpass --> NOUN
# , --> punct --> PUNCT
# obesity --> nsubjpass --> NOUN
# , --> punct --> PUNCT
# musculoskeletal --> amod --> ADJ
# TMEM222 --> conj --> PROPN
# was --> auxpass --> AUX
# once --> advmod --> ADV
# described --> ROOT --> VERB
# as --> prep --> ADP
# a --> det --> DET
# candidate --> compound --> NOUN
# gene --> pobj --> NOUN
# for --> prep --> ADP
# disorders --> pobj --> NOUN
# ( --> punct --> PUNCT
# hypotonia --> appos --> NOUN
# , --> punct --> PUNCT
# hypermobility --> conj --> NOUN
# , --> punct --> PUNCT
# kyphoscoliosis --> conj --> PROPN
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# ARIDD --> conj --> VERB
# with --> prep --> ADP
# moderate --> amod --> ADJ
# intellectual --> amod --> ADJ
# disability --> nmod --> NOUN
# , --> punct --> PUNCT
# speech --> compound --> NOUN
# delay --> pobj --> NOUN
# , --> punct --> PUNCT
# behavioural --> amod --> ADJ
# problems --> nsubj --> NOUN
# ( --> punct --> PUNCT
# autistic --> amod --> ADJ
# spectrum --> compound --> NOUN
# disorders --> appos --> NOUN
# ) --> punct --> PUNCT
# and --> cc --> CCONJ
# mild --> amod --> ADJ
# hypotonia --> conj --> NOUN
# , --> punct --> PUNCT
# aggressiveness --> conj --> NOUN
# and --> cc --> CCONJ
# body --> conj --> NOUN
# shivering --> conj --> VERB
# . --> punct --> PUNCT
# We --> nsubj --> PRON
# recently --> advmod --> ADV
# descri- --> ROOT --> X
# in --> prep --> ADP
# autistic --> amod --> ADJ
# brains --> pobj --> NOUN
# bed --> punct --> VERB
# a --> det --> DET
# novel --> amod --> ADJ
# method --> nsubjpass --> NOUN
# by --> prep --> ADP
# which --> pobj --> PRON
# the --> det --> DET
# protein --> nmod --> NOUN
# and --> cc --> CCONJ
# RNA --> conj --> NOUN
# contents --> relcl --> NOUN
# of --> prep --> ADP
# transcription --> compound --> NOUN
# M. --> compound --> PROPN
# Irimia1 --> pobj --> PROPN
# , --> punct --> PUNCT
# M. --> compound --> PROPN
# Quesnel --> compound --> PROPN
# - --> punct --> PUNCT
# Vallieres2 --> appos --> PROPN
# , --> punct --> PUNCT
# N. --> compound --> PROPN
# Parikshak3 --> conj --> PROPN
# , --> punct --> PUNCT
# D. --> compound --> PROPN
# H. --> compound --> PROPN
# Geschwind3 --> conj --> PROPN
# , --> punct --> PUNCT
# S. --> compound --> PROPN
# P. --> compound --> PROPN
# Cordes4 --> conj --> PROPN
# , --> punct --> PUNCT
# B. --> compound --> PROPN
# J. --> compound --> PROPN
# factories --> nsubjpass --> NOUN
# can --> aux --> AUX
# be --> auxpass --> AUX
# isolated --> ROOT --> VERB
# and --> cc --> CCONJ
# analyzed --> conj --> VERB
# in --> prep --> ADP
# a --> det --> DET
# high --> amod --> ADJ
# throughput --> compound --> NOUN
# fashion --> pobj --> NOUN
# . --> punct --> PUNCT
# Tran- --> nsubj --> VERB
# potentially --> advmod --> ADV
# with --> prep --> ADP
# underlying --> amod --> ADJ
# genetic --> amod --> ADJ
# variants --> pobj --> NOUN
# , --> punct --> PUNCT
# suggest --> ROOT --> VERB
# a --> det --> DET
# whole --> amod --> ADJ
# new --> amod --> ADJ
# way --> nsubj --> NOUN
# by --> prep --> ADP
# scriptomic --> compound --> ADJ
# profiling --> pobj --> PROPN
# has --> aux --> AUX
# revealed --> ccomp --> VERB
# consistently --> advmod --> ADV
# altered --> amod --> VERB
# signatures --> nsubj --> NOUN
# in --> prep --> ADP
# autistic --> pobj --> ADJ
# which --> nsubj --> PRON
# results --> relcl --> VERB
# from --> prep --> ADP
# both --> det --> CCONJ
# genetic --> amod --> ADJ
# and --> cc --> CCONJ
# functional --> conj --> ADJ
# studies --> pobj --> NOUN
# should --> aux --> AUX
# now --> advmod --> ADV
# be --> ccomp --> AUX
# ap- --> compound --> NOUN
# brains --> attr --> NOUN
# . --> punct --> PUNCT

# %%
pattern_1 = [{"TEXT": {"REGEX": "^[Aa]utistic$"}},
             {'DEP':'amod', 'OP':"?"},
             {'DEP':'amod', 'OP':"?"},
             {'DEP':'amod', 'OP':"?"},
             {"POS": "NOUN"}]

# %%
# Matcher class object 
matcher = Matcher(nlp.vocab) 
matcher.add("matching_1", [pattern_1]) 

autistic =[]

matches = matcher(person_doc) 
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = person_doc[start:end]  # The matched span
    autistic.append(span.text)

# %%
autistic_no_dups = list(set(autistic))
with open('..\\counts\\ESHG\\autism.csv', "w", encoding='ISO-8859-1') as outfile:
        write = csv.writer(outfile)
        for item in autistic_no_dups:
            write.writerow([item])

# %%
for item in autistic_no_dups:
    print(item)
# Out:
# autistic features
# autistic behaviour.individuals
# autistic boy
# autistic mole-
# autistic Basque sample
# autistic traits
# autistic behaviuor
# autistic behaviour.delayandbehavioraldisorder/ASDtraits,associatedwith
# autistic dis- ing
# autistic regression
# autistic patientâs
# autistic phenotype
# autistic variants
# autistic Results
# autistic trait
# autistic features,358 aggressiveness
# autistic behaviour
# autistic behaviour.8,9
# autistic subjects
# autistic variome
# autistic image
# autistic disorders
# autistic population
# autistic gene
# autistic spectrum
# autistic syndrome
# autistic ethnic populations
# autistic girl
# autistic traits.nal features
# autistic behavior
# autistic populations
# autistic indi- variability
# autistic patientsâ
# autistic group
# autistic microcephaly
# autistic brain
# autistic patients
# autistic child-
# autistic cases
# autistic symptoms
# autistic patient
# autistic syndromes
# autistic beha- disorder
# autistic groups
# autistic behaviour.1University
# autistic unrelated patients
# autistic features.feeding
# autistic valve
# autistic features.1PrÃ¤natal
# autistic behaviours
# autistic spectral disorders
# autistic child
# autistic features.dings
# autistic theadrenalcortex
# autistic brains
# autistic CGGs
# autistic small genomic deletions
# autistic probands
# autistic children
# autistic brains.individuals
# autistic dis-
# autistic disorder
# autistic dis- pathogenicmutation
# autistic causing
# autistic passivity
# autistic individuals
# Autistic population

# %%
pattern_2 = [{"POS": "NOUN"},
             {'LOWER': 'with'},
             {'DEP':'amod', 'OP':"?"},
             {'DEP':'amod', 'OP':"?"},
             {'DEP':'amod', 'OP':"?"},
             {"TEXT": {"REGEX": "^[Aa]utism$"}}]

# %%
# Matcher class object 
matcher = Matcher(nlp.vocab) 
matcher.add("matching_1", [pattern_2]) 

person_with =[]
matches = matcher(person_doc) 
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = person_doc[start:end]  # The matched span
    person_with.append(span.text)

# %%
person_with_no_dups = list(set(person_with))
with open('..\\counts\\ESHG\\person_with.csv', "w", encoding='ISO-8859-1') as outfile:
        write = csv.writer(outfile)
        for item in person_with_no_dups:
            write.writerow([item])
